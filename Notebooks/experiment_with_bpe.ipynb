# %%
def clean(text):
    texts=''
    for ch in text:
        if ch.isalnum() or ch==' ':
            texts+=ch.lower()
    return texts

# %%
def ch_token(text):
    clean_text=clean(text)
    ch_text=[]
    for ch in clean_text:
        if ch!=' ':
            ch_text.append(ch)
        else:
            ch_text.append('</w>')
    #print('ch_text:',ch_text,sep='\n',end='\n\n\n')
    return ch_text

# %%
def count_pair(text):
    ch_tokens=text
    Dcount_pair={}
    for i in range(0,len(ch_tokens)-1):
        if ch_tokens[i]=='</w>':
            continue
        pair=(ch_tokens[i],ch_tokens[i+1])
        if '</w>' not in pair:
            if pair not in Dcount_pair:
                Dcount_pair[pair]=1
            else:
                Dcount_pair[pair]+=1
    #print("dcount_pair",Dcount_pair,sep='\n')
    return Dcount_pair

# %%
def best_pair(text):
    pair_count=text
    max_count=0
    best=None
    for pair in pair_count:
        #print('pair',pair,'   pair_value',pair_count[pair],sep='     ',end='\n')
        if pair_count[pair]>max_count:
            max_count=pair_count[pair]
            #print('max count    ',max_count)
            best=pair
    #print('best',best)
    return best

# %%
'''def merge_best_pair(tokens,pair):
    new_tokens=[]
    i=0
    while i<len(tokens):
        if i<len(tokens)-1 and tokens[i]==pair[0] and tokens[i+1]==pair[1]:
            merged=tokens[i]+tokens[i+1]
            new_tokens.append(merged)
            i+=2
        else:
            new_tokens.append(tokens[i])
            i+=1
    return new_tokens
    '''
# Out:
# 'def merge_best_pair(tokens,pair):\n    new_tokens=[]\n    i=0\n    while i<len(tokens):\n        if i<len(tokens)-1 and tokens[i]==pair[0] and tokens[i+1]==pair[1]:\n            merged=tokens[i]+tokens[i+1]\n            new_tokens.append(merged)\n            i+=2\n        else:\n            new_tokens.append(tokens[i])\n            i+=1\n    return new_tokens\n    '

# %%
def merge_pair(tokens, pair):

    new_tokens = []
    i = 0

    while i < len(tokens):

        if i < len(tokens)-1 and tokens[i] == pair[0] and tokens[i+1] == pair[1]:

            new_tokens.append(tokens[i] + tokens[i+1])
            i += 2

        else:
            new_tokens.append(tokens[i])
            i += 1

    return new_tokens

# %%
'''def train_bpe(text,iterations):
    tokens=ch_token(text)
    for i in range(iterations):
        pair_counts=count_pair(tokens)
        pair=best_pair(pair_counts)
        if pair_counts[pair]==1 :
            break
        #print('merge pair:',pair)
        tokens=merge_best_pair(tokens,pair)
        #print('updated tokens:',tokens)
    return tokens
'''
# Out:
# "def train_bpe(text,iterations):\n    tokens=ch_token(text)\n    for i in range(iterations):\n        pair_counts=count_pair(tokens)\n        pair=best_pair(pair_counts)\n        if pair_counts[pair]==1 :\n            break\n        #print('merge pair:',pair)\n        tokens=merge_best_pair(tokens,pair)\n        #print('updated tokens:',tokens)\n    return tokens\n"

# %%
def get_vocab(tokens):

    vocab=set()

    for tok in tokens:
        vocab.add(tok)

    return vocab

# %%
'''def train_bpe(text,iterations):
    tokens=ch_token(text)
    merge=[]
    for i in range(iterations):
        pair_counts=count_pair(tokens)
        pair=best_pair(pair_counts)
        if pair is None:
            break
        if pair_count[pair]==1:
            break
        merges.append(pair)
        print('merge: ',pair)
        tokens=merge_best_pair(tokens,pair)
    return merges'''
# Out:
# "def train_bpe(text,iterations):\n    tokens=ch_token(text)\n    merge=[]\n    for i in range(iterations):\n        pair_counts=count_pair(tokens)\n        pair=best_pair(pair_counts)\n        if pair is None:\n            break\n        if pair_count[pair]==1:\n            break\n        merges.append(pair)\n        print('merge: ',pair)\n        tokens=merge_best_pair(tokens,pair)\n    return merges"

# %%
'''def train_bpe(text, max_vocab):
    tokens = ch_token(text)
    merges = []
    while True:
        pair_counts = count_pair(tokens)
        pair = best_pair(pair_counts)
        if pair is None:
            break
        if pair_counts[pair] == 1:
            break
        merges.append(pair)
        tokens = merge_pair(tokens, pair)
        vocab = get_vocab(tokens)
        print("merge:", pair, " vocab size:", len(vocab))
        if len(vocab) >= max_vocab:
            break
    return tokens, merges'''
# Out:
# 'def train_bpe(text, max_vocab):\n    tokens = ch_token(text)\n    merges = []\n    while True:\n        pair_counts = count_pair(tokens)\n        pair = best_pair(pair_counts)\n        if pair is None:\n            break\n        if pair_counts[pair] == 1:\n            break\n        merges.append(pair)\n        tokens = merge_pair(tokens, pair)\n        vocab = get_vocab(tokens)\n        print("merge:", pair, " vocab size:", len(vocab))\n        if len(vocab) >= max_vocab:\n            break\n    return tokens, merges'

# %%
def train_bpe(text, max_vocab):
    tokens = ch_token(text)
    merges = []
    while True:
        pair_counts = count_pair(tokens)
        pair = best_pair(pair_counts)
        if pair is None:
            break
        if pair_counts[pair] == 1:
            break
        merges.append(pair)
        tokens = merge_pair(tokens, pair)
        vocab = get_vocab(tokens)
        print("merge:", pair, " vocab size:", len(vocab))
        if len(vocab) >= max_vocab:
            break
    return tokens, merges

# %%
def build_vocab(vocab):

    vocab_dict = {}
    id = 0

    for token in vocab:
        vocab_dict[token] = id
        id += 1

    return vocab_dict

# %%
def reverse_vocab(vocab_dict):

    rev = {}

    for token in vocab_dict:
        rev[vocab_dict[token]] = token

    return rev

# %%
def encode(text, merges, vocab_dict):

    tokens = ch_token(text)

    for pair in merges:
        tokens = merge_pair(tokens, pair)

    ids = []

    for token in tokens:
        ids.append(vocab_dict[token])

    return ids

# %%
def decode(ids, rev_vocab):

    tokens = []

    for i in ids:
        tokens.append(rev_vocab[i])

    text = ""

    for token in tokens:
        if token == "</w>":
            text += " "
        else:
            text += token

    return text.strip()

# %%
vocab=int(input('enter number of vocab:'))
text_in=input('enter:')
merge=train_bpe(text_in,vocab)
print('bpe of given text is :',merge, sep='\n')
# Out:
# enter number of vocab:1500
# enter: WikipediaThe Free Encyclopedia Search Wikipedia Search Donate Create account Log in Wiki Loves Folklore Logo Wiki Loves Folklore Photograph your local culture, help Wikipedia and win! Participate Now Folklore Graphics [Help with translations!] Contents hide (Top) Etymology History  Geography  Government and politics  Economy  Demographics  Culture  See also Notes References Bibliography  External links India  Article Talk Read View source View history  Tools Appearance hide Birthday mode (Baby Globe)  Disabled  Enabled Learn more about Birthday mode Text  Small  Standard  Large Width  Standard  Wide Color (beta)  Automatic  Light  Dark Coordinates: 21°N 78°E Featured article Extended-protected article From Wikipedia, the free encyclopedia This article is about the country. For other uses, see India (disambiguation). Republic of India Bhārat Gaṇarājya Horizontal tricolour flag bearing, from top to bottom, deep saffron, white, and green horizontal bands. In the centre of the white band is a navy-blue wheel with 24 spokes. Flag  State emblem Motto: Satyameva Jayate (Sanskrit) "Truth Alone Triumphs"[1] Anthem: Jana Gana Mana (Hindi)[a][2][3] "Thou Art the Ruler of the Minds of All People"[4][2] Duration: 1 minute and 4 seconds.1:04 National song: Vande Mataram (Sanskrit)[c] "I Bow to Thee, Mother"[b][1][2] Duration: 2 minutes and 26 seconds.2:26 Image of a globe centred on India, with India highlighted.   Territory controlled by India   Territory claimed but not controlled Capital	New Delhi 28°36′50″N 77°12′30″E Largest city by city proper population	Mumbai Largest city by metropolitan area population	Delhi Official languages	 HindiEnglish[d][8] Recognised regional languages	 State level and Eighth Schedule[9] Native languages	424 languages[g] Religion (2011)[11]	 79.8% Hinduism 14.2% Islam 2.3% Christianity 1.7% Sikhism 0.7% Buddhism 0.4% Jainism 0.23% unaffiliated 0.65% other Demonyms	 Indianothers Government	Federal parliamentary republic • President Droupadi Murmu • Vice President C. P. Radhakrishnan • Prime Minister Narendra Modi Legislature	Parliament • Upper house Rajya Sabha • Lower house Lok Sabha Independence from the United Kingdom • Dominion 15 August 1947 • Republic 26 January 1950 Area • Total 3,287,263 km2 (1,269,219 sq mi)[7][h] (7th) • Water (%) 9.6 Population • 2023 estimate Neutral increase 1,428,627,663[13] (1st) • 2011 census Neutral increase 1,210,854,977[14][15] (2nd) • Density 433.4/km2 (1,122.5/sq mi) (30th) GDP (PPP)	2025 estimate • Total Increase $17.647 trillion[16] (3rd) • Per capita Increase $12,132[16] (119th) GDP (nominal)	2025 estimate • Total Increase $4.187 trillion[16] (4th) • Per capita Increase $2,878[16] (136th) Gini (2022)	Positive decrease 25.5[17] low inequality HDI (2023)	Increase 0.685[18] medium (130th) Currency	Indian rupee (₹) (INR) Time zone	UTC+05:30 (IST) Date format	 dd-mm-yyyy[i] Calling code	+91 ISO 3166 code	IN Internet TLD	.in (others) India, officially the Republic of India,[j][20] is a country in South Asia. It is the seventh-largest country by area; the most populous country since 2023;[21] and, since its independence in 1947, the world's most populous democracy.[22][23][24] Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[k] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is near Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Myanmar, Thailand, and Indonesia.  Modern humans arrived on the Indian subcontinent from Africa no later than 55,000 years ago.[26][27][28] Their long occupation, predominantly in isolation as hunter-gatherers, has made the region highly diverse.[29] Settled life emerged on the subcontinent in the western margins of the Indus river basin 9,000 years ago, evolving gradually into the Indus Valley Civilisation of the third millennium  ...
# merge: ('i', 'n')  vocab size: 74
# merge: ('t', 'h')  vocab size: 75
# merge: ('a', 'n')  vocab size: 76
# merge: ('th', 'e')  vocab size: 77
# merge: ('e', 'r')  vocab size: 78
# merge: ('o', 'n')  vocab size: 79
# merge: ('a', 'r')  vocab size: 80
# merge: ('a', 'l')  vocab size: 81
# merge: ('e', 'n')  vocab size: 82
# merge: ('r', 'e')  vocab size: 83
# merge: ('t', 'i')  vocab size: 84
# merge: ('d', 'i')  vocab size: 85
# merge: ('e', 'd')  vocab size: 86
# merge: ('o', 'r')  vocab size: 87
# merge: ('s', 't')  vocab size: 88
# merge: ('o', 'f')  vocab size: 89
# merge: ('an', 'd')  vocab size: 90
# merge: ('2', '0')  vocab size: 91
# merge: ('a', 's')  vocab size: 92
# merge: ('i', 's')  vocab size: 93
# merge: ('in', 'di')  vocab size: 94
# merge: ('e', 's')  vocab size: 95
# merge: ('a', 't')  vocab size: 96
# merge: ('r', 'i')  vocab size: 97
# merge: ('r', 'o')  vocab size: 98
# merge: ('c', 'h')  vocab size: 99
# merge: ('ti', 'on')  vocab size: 100
# merge: ('in', 'g')  vocab size: 101
# merge: ('t', 'o')  vocab size: 102
# merge: ('i', 't')  vocab size: 103
# merge: ('en', 't')  vocab size: 104
# merge: ('indi', 'a')  vocab size: 105
# merge: ('l', 'e')  vocab size: 106
# merge: ('o', 'u')  vocab size: 107
# merge: ('r', 'a')  vocab size: 108
# merge: ('l', 'i')  vocab size: 109
# merge: ('20', '1')  vocab size: 110
# merge: ('o', 'm')  vocab size: 111
# merge: ('d', 'e')  vocab size: 112
# merge: ('a', 'm')  vocab size: 113
# merge: ('l', 'y')  vocab size: 114
# merge: ('i', 'c')  vocab size: 115
# merge: ('s', 'e')  vocab size: 116
# merge: ('c', 'on')  vocab size: 117
# merge: ('1', '9')  vocab size: 118
# merge: ('u', 'n')  vocab size: 119
# merge: ('m', 'a')  vocab size: 120
# merge: ('c', 'e')  vocab size: 121
# merge: ('v', 'er')  vocab size: 122
# merge: ('g', 'e')  vocab size: 123
# merge: ('a', 'tion')  vocab size: 124
# merge: ('h', 'i')  vocab size: 125
# merge: ('u', 'r')  vocab size: 126
# merge: ('f', 'or')  vocab size: 127
# merge: ('v', 'e')  vocab size: 128
# merge: ('o', 'l')  vocab size: 129
# merge: ('i', 'l')  vocab size: 130
# merge: ('b', 'e')  vocab size: 131
# merge: ('20', '0')  vocab size: 132
# merge: ('v', 'ed')  vocab size: 133
# merge: ('u', 'l')  vocab size: 134
# merge: ('re', 's')  vocab size: 135
# merge: ('e', 'm')  vocab size: 136
# merge: ('u', 's')  vocab size: 137
# merge: ('t', 'er')  vocab size: 138
# merge: ('l', 'o')  vocab size: 139
# merge: ('p', 'o')  vocab size: 140
# merge: ('m', 'o')  vocab size: 141
# merge: ('a', 'd')  vocab size: 142
# merge: ('t', 'ri')  vocab size: 143
# merge: ('c', 'i')  vocab size: 144
# merge: ('7', '8')  vocab size: 145
# merge: ('ro', 'm')  vocab size: 146
# merge: ('i', 'r')  vocab size: 147
# merge: ('p', 'p')  vocab size: 148
# merge: ('m', 'e')  vocab size: 149
# merge: ('s', 'i')  vocab size: 150
# merge: ('b', 'y')  vocab size: 151
# merge: ('ti', 'c')  vocab size: 152
# merge: ('f', 'rom')  vocab size: 153
# merge: ('an', 'g')  vocab size: 154
# merge: ('indi', 'an')  vocab size: 155
# merge: ('it', 'y')  vocab size: 156
# merge: ('d', 'u')  vocab size: 157
# merge: ('a', 'st')  vocab size: 158
# merge: ('w', 'i')  vocab size: 159
# merge: ('m', 'ent')  vocab size: 160
# merge: ('b', 'er')  vocab size: 161
# merge: ('1', '0')  vocab size: 162
# merge: ('9', '78')  vocab size: 163
# merge: ('p', 'e')  vocab size: 164
# merge: ('a', 'c')  vocab size: 165
# merge: ('b', 'n')  vocab size: 166
# merge: ('is', 'bn')  vocab size: 167
# merge: ('t', 'e')  vocab size: 168
# merge: ('w', 'e')  vocab size: 169
# merge: ('g', 'h')  vocab size: 170
# merge: ('s', 'h')  vocab size: 171
# merge: ('t', 'u')  vocab size: 172
# merge: ('a', 'b')  vocab size: 173
# merge: ('c', 'om')  vocab size: 174
# merge: ('s', 'u')  vocab size: 175
# merge: ('a', 'g')  vocab size: 176
# merge: ('at', 'e')  vocab size: 177
# merge: ('e', 'ved')  vocab size: 178
# merge: ('i', 'on')  vocab size: 179
# merge: ('ar', 'y')  vocab size: 180
# merge: ('p', 'er')  vocab size: 181
# merge: ('re', 'tri')  vocab size: 182
# merge: ('retri', 'eved')  vocab size: 182
# merge: ('i', 'g')  vocab size: 183
# merge: ('n', 'e')  vocab size: 184
# merge: ('a', 'k')  vocab size: 185
# merge: ('w', 'or')  vocab size: 186
# merge: ('wi', 'th')  vocab size: 187
# merge: ('a', 'y')  vocab size: 188
# merge: ('u', 't')  vocab size: 189
# merge: ('res', 's')  vocab size: 190
# merge: ('20', '2')  vocab size: 191
# merge: ('l', 'd')  vocab size: 192
# merge: ('w', 'as')  vocab size: 193
# merge: ('i', 'st')  vocab size: 194
# merge: ('p', 'ar')  vocab size: 195
# merge: ('m', 'an')  vocab size: 196
# merge: ('0', '0')  vocab size: 197
# merge: ('d', 'er')  vocab size: 198
# merge: ('e', 'x')  vocab size: 199
# merge: ('n', 'o')  vocab size: 200
# merge: ('s', 'o')  vocab size: 201
# merge: ('p', 'l')  vocab size: 202
# merge: ('ar', 'ch')  vocab size: 203
# merge: ('c', 'ent')  vocab size: 204
# merge: ('t', 's')  vocab size: 205
# merge: ('v', 'i')  vocab size: 206
# merge: ('ver', 's')  vocab size: 207
# merge: ('1', '1')  vocab size: 208
# merge: ('o', 'ver')  vocab size: 209
# merge: ('p', 'ro')  vocab size: 210
# merge: ('the', 'r')  vocab size: 211
# merge: ('1', '2')  vocab size: 212
# merge: ('ar', 'e')  vocab size: 213
# merge: ('er', 'e')  vocab size: 214
# merge: ('c', 'al')  vocab size: 215
# merge: ('a', 'f')  vocab size: 216
# merge: ('indi', 'as')  vocab size: 217
# merge: ('vers', 'ity')  vocab size: 218
# merge: ('c', 'l')  vocab size: 219
# merge: ('r', 'u')  vocab size: 220
# merge: ('1', '8')  vocab size: 221
# merge: ('1', '7')  vocab size: 222
# merge: ('o', 'g')  vocab size: 223
# merge: ('s', 'ou')  vocab size: 224
# merge: ('a', 'p')  vocab size: 225
# merge: ('201', '1')  vocab size: 226
# merge: ('ou', 'n')  vocab size: 227
# merge: ('h', 'in')  vocab size: 228
# merge: ('19', '9')  vocab size: 229
# merge: ('m', 'ar')  vocab size: 230
# merge: ('c', 't')  vocab size: 231
# merge: ('wor', 'ld')  vocab size: 232
# merge: ('a', 'ge')  vocab size: 233
# merge: ('w', 'hi')  vocab size: 234
# merge: ('978', '0')  vocab size: 235
# merge: ('e', 'ar')  vocab size: 236
# merge: ('un', 'i')  vocab size: 237
# merge: ('p', 'ress')  vocab size: 238
# merge: ('b', 'o')  vocab size: 239
# merge: ('l', 'ang')  vocab size: 240
# merge: ('1', '3')  vocab size: 241
# merge: ('is', 'h')  vocab size: 242
# merge: ('1', '4')  vocab size: 243
# merge: ('u', 'd')  vocab size: 244
# merge: ('whi', 'ch')  vocab size: 245
# merge: ('c', 'o')  vocab size: 246
# merge: ('w', 'h')  vocab size: 247
# merge: ('in', 'al')  vocab size: 248
# merge: ('lang', 'u')  vocab size: 249
# merge: ('1', '5')  vocab size: 250
# merge: ('f', 'o')  vocab size: 251
# merge: ('al', 'l')  vocab size: 252
# merge: ('h', 'a')  vocab size: 253
# merge: ('1', '6')  vocab size: 254
# merge: ('as', 'i')  vocab size: 255
# merge: ('b', 'ri')  vocab size: 256
# merge: ('or', 'y')  vocab size: 257
# merge: ('f', 'e')  vocab size: 258
# merge: ('a', 'in')  vocab size: 259
# merge: ('h', 'as')  vocab size: 260
# merge: ('or', 'ig')  vocab size: 261
# merge: ('hi', 'st')  vocab size: 262
# merge: ('n', 'ation')  vocab size: 263
# merge: ('on', 'g')  vocab size: 264
# merge: ('i', 'd')  vocab size: 265
# merge: ('an', 's')  vocab size: 266
# merge: ('in', 'e')  vocab size: 267
# merge: ('u', 'm')  vocab size: 268
# merge: ('s', 'ti')  vocab size: 269
# merge: ('o', 'd')  vocab size: 270
# merge: ('uni', 'versity')  vocab size: 271
# merge: ('th', 'at')  vocab size: 272
# merge: ('ou', 'r')  vocab size: 273
# merge: ('it', 's')  vocab size: 274
# merge: ('e', 't')  vocab size: 275
# merge: ('en', 'ce')  vocab size: 276
# merge: ('c', 'tion')  vocab size: 277
# merge: ('m', 'in')  vocab size: 278
# merge: ('u', 'p')  vocab size: 279
# merge: ('al', 'ly')  vocab size: 280
# merge: ('r', 'y')  vocab size: 281
# merge: ('hin', 'du')  vocab size: 282
# merge: ('2', '3')  vocab size: 283
# merge: ('i', 'm')  vocab size: 284
# merge: ('h', 'ar')  vocab size: 285
# merge: ('orig', 'inal')  vocab size: 286
# merge: ('m', 'il')  vocab size: 287
# merge: ('con', 't')  vocab size: 288
# merge: ('2', '6')  vocab size: 289
# merge: ('as', 's')  vocab size: 290
# merge: ('re', 'g')  vocab size: 291
# merge: ('l', 'ed')  vocab size: 292
# merge: ('for', 'm')  vocab size: 293
# merge: ('j', 'u')  vocab size: 294
# merge: ('i', 'ved')  vocab size: 295
# merge: ('c', 'ul')  vocab size: 296
# merge: ('p', 'u')  vocab size: 297
# merge: ('en', 'g')  vocab size: 298
# merge: ('e', 'con')  vocab size: 299
# merge: ('econ', 'om')  vocab size: 299
# merge: ('2', '8')  vocab size: 300
# merge: ('f', 'ic')  vocab size: 301
# merge: ('er', 's')  vocab size: 302
# merge: ('em', 'p')  vocab size: 303
# merge: ('en', 'd')  vocab size: 304
# merge: ('d', 'o')  vocab size: 305
# merge: ('sou', 'th')  vocab size: 306
# merge: ('sti', 'tu')  vocab size: 307
# merge: ('a', 'u')  vocab size: 308
# merge: ('t', 'ra')  vocab size: 309
# merge: ('arch', 'ived')  vocab size: 310
# merge: ('is', 'm')  vocab size: 311
# merge: ('g', 'en')  vocab size: 312
# merge: ('g', 'over')  vocab size: 313
# merge: ('gover', 'n')  vocab size: 313
# merge: ('nation', 'al')  vocab size: 314
# merge: ('at', 'ed')  vocab size: 315
# merge: ('w', 'ere')  vocab size: 316
# merge: ('c', 'y')  vocab size: 317
# merge: ('c', 'am')  vocab size: 318
# merge: ('me', 't')  vocab size: 319
# merge: ('o', 'c')  vocab size: 320
# merge: ('w', 'ar')  vocab size: 321
# merge: ('ri', 't')  vocab size: 322
# merge: ('g', 'u')  vocab size: 323
# merge: ('govern', 'ment')  vocab size: 324
# merge: ('a', 'v')  vocab size: 325
# merge: ('2', '5')  vocab size: 326
# merge: ('p', 'ul')  vocab size: 327
# merge: ('ic', 'al')  vocab size: 328
# merge: ('p', 't')  vocab size: 329
# merge: ('p', 'h')  vocab size: 330
# merge: ('a', 'ti')  vocab size: 331
# merge: ('fo', 're')  vocab size: 332
# merge: ('tu', 're')  vocab size: 333
# merge: ('hist', 'ory')  vocab size: 334
# merge: ('c', 'es')  vocab size: 335
# merge: ('an', 'ce')  vocab size: 336
# merge: ('l', 'ar')  vocab size: 337
# merge: ('2', '4')  vocab size: 338
# merge: ('q', 'u')  vocab size: 339
# merge: ('as', 'h')  vocab size: 340
# merge: ('for', 'd')  vocab size: 341
# merge: ('ag', 'es')  vocab size: 342
# merge: ('201', '0')  vocab size: 343
# merge: ('cal', 'f')  vocab size: 344
# merge: ('t', 'al')  vocab size: 345
# merge: ('ne', 'w')  vocab size: 346
# merge: ('po', 'pul')  vocab size: 347
# merge: ('n', 'or')  vocab size: 348
# merge: ('p', 'or')  vocab size: 349
# merge: ('g', 'ro')  vocab size: 350
# merge: ('o', 'x')  vocab size: 351
# merge: ('con', 'stitu')  vocab size: 352
# merge: ('met', 'calf')  vocab size: 353
# merge: ('at', 'es')  vocab size: 354
# merge: ('we', 'st')  vocab size: 355
# merge: ('c', 'ast')  vocab size: 356
# merge: ('4', '0')  vocab size: 357
# merge: ('f', 'ir')  vocab size: 358
# merge: ('ox', 'ford')  vocab size: 359
# merge: ('k', 'e')  vocab size: 360
# merge: ('th', 'is')  vocab size: 361
# merge: ('5', '0')  vocab size: 362
# merge: ('af', 'ter')  vocab size: 363
# merge: ('c', 're')  vocab size: 364
# merge: ('di', 's')  vocab size: 365
# merge: ('t', 'a')  vocab size: 366
# merge: ('so', 'ci')  vocab size: 367
# merge: ('p', 'an')  vocab size: 368
# merge: ('s', 'y')  vocab size: 369
# merge: ('em', 'ber')  vocab size: 370
# merge: ('lar', 'ge')  vocab size: 371
# merge: ('lo', 'w')  vocab size: 372
# merge: ('2', '7')  vocab size: 373
# merge: ('ou', 's')  vocab size: 374
# merge: ('y', 'ear')  vocab size: 375
# merge: ('2', '9')  vocab size: 376
# merge: ('l', 'l')  vocab size: 377
# merge: ('3', '0')  vocab size: 378
# merge: ('i', 'al')  vocab size: 379
# merge: ('su', 'b')  vocab size: 380
# merge: ('er', 'n')  vocab size: 381
# merge: ('ma', 'in')  vocab size: 382
# merge: ('com', 'm')  vocab size: 383
# merge: ('on', 'e')  vocab size: 384
# merge: ('ju', 'ly')  vocab size: 385
# merge: ('b', 'i')  vocab size: 386
# merge: ('c', 'ol')  vocab size: 387
# merge: ('re', 'li')  vocab size: 388
# merge: ('fir', 'st')  vocab size: 389
# merge: ('s', 'er')  vocab size: 390
# merge: ('ou', 't')  vocab size: 391
# merge: ('gh', 't')  vocab size: 392
# merge: ('g', 'an')  vocab size: 393
# merge: ('b', 'ut')  vocab size: 394
# merge: ('asi', 'a')  vocab size: 395
# merge: ('ur', 'ing')  vocab size: 396
# merge: ('201', '8')  vocab size: 397
# merge: ('po', 'li')  vocab size: 398
# merge: ('pu', 'b')  vocab size: 399
# merge: ('min', 'ist')  vocab size: 400
# merge: ('e', 'ast')  vocab size: 401
# merge: ('p', 'r')  vocab size: 402
# merge: ('ha', 've')  vocab size: 403
# merge: ('par', 't')  vocab size: 404
# merge: ('no', 't')  vocab size: 405
# merge: ('li', 'c')  vocab size: 406
# merge: ('p', 'le')  vocab size: 407
# merge: ('reg', 'ion')  vocab size: 408
# merge: ('p', 're')  vocab size: 409
# merge: ('d', 'es')  vocab size: 410
# merge: ('s', 'pe')  vocab size: 411
# merge: ('at', 'er')  vocab size: 412
# merge: ('3', '3')  vocab size: 413
# merge: ('li', 'on')  vocab size: 414
# merge: ('langu', 'age')  vocab size: 415
# merge: ('ur', 'y')  vocab size: 416
# merge: ('i', 'es')  vocab size: 417
# merge: ('di', 'tion')  vocab size: 418
# merge: ('be', 't')  vocab size: 419
# merge: ('c', 'oun')  vocab size: 420
# merge: ('h', 'e')  vocab size: 421
# merge: ('ti', 'm')  vocab size: 422
# merge: ('in', 'ter')  vocab size: 423
# merge: ('ch', 'in')  vocab size: 424
# merge: ('cast', 'e')  vocab size: 425
# merge: ('m', 'us')  vocab size: 426
# merge: ('u', 'c')  vocab size: 427
# merge: ('o', 'k')  vocab size: 428
# merge: ('om', 'e')  vocab size: 429
# merge: ('19', '6')  vocab size: 430
# merge: ('l', 'and')  vocab size: 431
# merge: ('w', 'n')  vocab size: 432
# merge: ('d', 'uring')  vocab size: 433
# merge: ('g', 'ra')  vocab size: 434
# merge: ('j', 'an')  vocab size: 435
# merge: ('popul', 'ation')  vocab size: 436
# merge: ('of', 'fic')  vocab size: 437
# merge: ('l', 'ish')  vocab size: 438
# merge: ('ud', 'd')  vocab size: 439
# merge: ('m', 'u')  vocab size: 440
# merge: ('4', '7')  vocab size: 441
# merge: ('mo', 'st')  vocab size: 442
# merge: ('mo', 'der')  vocab size: 443
# merge: ('the', 'ir')  vocab size: 444
# merge: ('in', 'to')  vocab size: 445
# merge: ('cl', 'ass')  vocab size: 446
# merge: ('s', 'on')  vocab size: 447
# merge: ('al', 'i')  vocab size: 448
# merge: ('un', 'd')  vocab size: 449
# merge: ('201', '9')  vocab size: 450
# merge: ('200', '6')  vocab size: 451
# merge: ('200', '7')  vocab size: 452
# merge: ('f', 'er')  vocab size: 453
# merge: ('langu', 'ages')  vocab size: 453
# merge: ('er', 'al')  vocab size: 454
# merge: ('p', 'ri')  vocab size: 455
# merge: ('2', '2')  vocab size: 456
# merge: ('in', 'd')  vocab size: 457
# merge: ('3', '5')  vocab size: 458
# merge: ('constitu', 'tion')  vocab size: 459
# merge: ('n', 'a')  vocab size: 460
# merge: ('st', 'e')  vocab size: 461
# merge: ('ma', 'y')  vocab size: 462
# merge: ('k', 'ar')  vocab size: 463
# merge: ('d', 'f')  vocab size: 464
# merge: ('ol', 'og')  vocab size: 465
# merge: ('moder', 'n')  vocab size: 466
# merge: ('cont', 'in')  vocab size: 467
# merge: ('t', 'w')  vocab size: 468
# merge: ('c', 'ed')  vocab size: 469
# merge: ('p', 'df')  vocab size: 470
# merge: ('tic', 's')  vocab size: 471
# merge: ('al', 'so')  vocab size: 472
# merge: ('mo', 're')  vocab size: 473
# merge: ('v', 'en')  vocab size: 474
# merge: ('cent', 'ury')  vocab size: 475
# merge: ('reli', 'g')  vocab size: 476
# merge: ('an', 't')  vocab size: 477
# merge: ('a', 'ch')  vocab size: 478
# merge: ('l', 'es')  vocab size: 479
# merge: ('lo', 'p')  vocab size: 480
# merge: ('re', 'e')  vocab size: 481
# merge: ('or', 'd')  vocab size: 482
# merge: ('s', 'ch')  vocab size: 483
# merge: ('m', 'i')  vocab size: 484
# merge: ('c', 'a')  vocab size: 485
# merge: ('year', 's')  vocab size: 486
# merge: ('econom', 'ic')  vocab size: 487
# merge: ('si', 'on')  vocab size: 488
# merge: ('h', 'o')  vocab size: 489
# merge: ('b', 'an')  vocab size: 490
# merge: ('201', '4')  vocab size: 491
# merge: ('e', 'l')  vocab size: 492
# merge: ('p', 'res')  vocab size: 493
# merge: ('c', 'ri')  vocab size: 494
# merge: ('bet', 'we')  vocab size: 495
# merge: ('betwe', 'en')  vocab size: 495
# merge: ('202', '1')  vocab size: 496
# merge: ('pub', 'lic')  vocab size: 497
# merge: ('n', 'i')  vocab size: 498
# merge: ('e', 'st')  vocab size: 499
# merge: ('r', 'an')  vocab size: 500
# merge: ('ti', 'es')  vocab size: 501
# merge: ('d', 'ge')  vocab size: 502
# merge: ('ar', 'd')  vocab size: 503
# merge: ('f', 'l')  vocab size: 504
# merge: ('3', '6')  vocab size: 505
# merge: ('m', 'al')  vocab size: 506
# merge: ('sy', 'st')  vocab size: 507
# merge: ('syst', 'em')  vocab size: 507
# merge: ('e', 'le')  vocab size: 508
# merge: ('f', 'i')  vocab size: 509
# merge: ('ti', 've')  vocab size: 510
# merge: ('h', 'u')  vocab size: 511
# merge: ('ar', 'i')  vocab size: 512
# merge: ('n', 'um')  vocab size: 513
# merge: ('19', '8')  vocab size: 514
# merge: ('d', 'y')  vocab size: 515
# merge: ('bri', 'dge')  vocab size: 516
# merge: ('ar', 'tic')  vocab size: 517
# merge: ('o', 'ther')  vocab size: 518
# merge: ('r', 'is')  vocab size: 519
# merge: ('en', 's')  vocab size: 520
# merge: ('oun', 'd')  vocab size: 521
# merge: ('v', 'al')  vocab size: 522
# merge: ('tic', 'al')  vocab size: 523
# merge: ('t', 'ed')  vocab size: 524
# merge: ('de', 've')  vocab size: 525
# merge: ('oc', 'to')  vocab size: 526
# merge: ('octo', 'ber')  vocab size: 526
# merge: ('19', '7')  vocab size: 527
# merge: ('s', 'ans')  vocab size: 528
# merge: ('large', 'st')  vocab size: 529
# merge: ('d', 'om')  vocab size: 530
# merge: ('h', 'ad')  vocab size: 531
# merge: ('po', 's')  vocab size: 532
# merge: ('t', 'ro')  vocab size: 533
# merge: ('be', 'en')  vocab size: 534
# merge: ('s', 'ome')  vocab size: 535
# merge: ('wh', 'o')  vocab size: 536
# merge: ('un', 'e')  vocab size: 537
# merge: ('p', 'ra')  vocab size: 538
# merge: ('se', 'pt')  vocab size: 539
# merge: ('sept', 'ember')  vocab size: 539
# merge: ('ation', 's')  vocab size: 540
# merge: ('au', 'gu')  vocab size: 541
# merge: ('augu', 'st')  vocab size: 541
# merge: ('cre', 'as')  vocab size: 542
# merge: ('in', 'ce')  vocab size: 543
# merge: ('3', '8')  vocab size: 544
# merge: ('3', '9')  vocab size: 545
# merge: ('a', 'w')  vocab size: 546
# merge: ('al', 'th')  vocab size: 547
# merge: ('deve', 'lop')  vocab size: 548
# merge: ('ri', 'l')  vocab size: 549
# merge: ('200', '8')  vocab size: 550
# merge: ('201', '2')  vocab size: 551
# merge: ('cam', 'bridge')  vocab size: 552
# merge: ('sans', 'k')  vocab size: 553
# merge: ('m', 'on')  vocab size: 554
# merge: ('202', '3')  vocab size: 555
# merge: ('c', 'ra')  vocab size: 556
# merge: ('th', 'an')  vocab size: 557
# merge: ('l', 'ong')  vocab size: 558
# merge: ('m', 'id')  vocab size: 559
# merge: ('f', 't')  vocab size: 560
# merge: ('bri', 'ti')  vocab size: 561
# merge: ('briti', 'sh')  vocab size: 561
# merge: ('am', 'ong')  vocab size: 562
# merge: ('the', 're')  vocab size: 563
# merge: ('b', 'al')  vocab size: 564
# merge: ('un', 'der')  vocab size: 565
# merge: ('ap', 'ril')  vocab size: 566
# merge: ('200', '9')  vocab size: 567
# merge: ('it', 'e')  vocab size: 568
# merge: ('de', 'l')  vocab size: 569
# merge: ('k', 'ing')  vocab size: 570
# merge: ('me', 'di')  vocab size: 571
# merge: ('contin', 'ent')  vocab size: 572
# merge: ('b', 'ce')  vocab size: 573
# merge: ('cam', 'e')  vocab size: 574
# merge: ('h', 'er')  vocab size: 575
# merge: ('tw', 'o')  vocab size: 576
# merge: ('ur', 'al')  vocab size: 577
# merge: ('tra', 'dition')  vocab size: 578
# merge: ('in', 'cl')  vocab size: 579
# merge: ('tim', 'es')  vocab size: 580
# merge: ('num', 'ber')  vocab size: 581
# merge: ('n', 'at')  vocab size: 582
# merge: ('g', 'ress')  vocab size: 583
# merge: ('ma', 'the')  vocab size: 584
# merge: ('t', 'r')  vocab size: 585
# merge: ('sansk', 'rit')  vocab size: 586
# merge: ('offic', 'ial')  vocab size: 587
# merge: ('in', 'creas')  vocab size: 588
# merge: ('4', '9')  vocab size: 589
# merge: ('c', 'ur')  vocab size: 590
# merge: ('west', 'ern')  vocab size: 591
# merge: ('us', 'ed')  vocab size: 592
# merge: ('ther', 'n')  vocab size: 593
# merge: ('t', 'en')  vocab size: 594
# merge: ('do', 'i')  vocab size: 595
# merge: ('p', 'ic')  vocab size: 596
# merge: ('at', 'a')  vocab size: 597
# merge: ('v', 'is')  vocab size: 598
# merge: ('c', 'k')  vocab size: 599
# merge: ('s', 'ur')  vocab size: 600
# merge: ('j', 'une')  vocab size: 601
# merge: ('mus', 'ic')  vocab size: 602
# merge: ('olog', 'y')  vocab size: 603
# merge: ('a', 'pp')  vocab size: 604
# merge: ('re', 'd')  vocab size: 605
# merge: ('g', 're')  vocab size: 606
# merge: ('b', 'udd')  vocab size: 607
# merge: ('r', 'al')  vocab size: 608
# merge: ('e', 'u')  vocab size: 609
# merge: ('emp', 'i')  vocab size: 610
# merge: ('3', '7')  vocab size: 611
# merge: ('com', 'pan')  vocab size: 612
# merge: ('ac', 't')  vocab size: 613
# merge: ('n', 'am')  vocab size: 614
# merge: ('t', 'am')  vocab size: 615
# merge: ('s', 'ing')  vocab size: 616
# merge: ('con', 'gress')  vocab size: 617
# merge: ('mathe', 'ma')  vocab size: 618
# merge: ('ed', 's')  vocab size: 619
# merge: ('doi', '10')  vocab size: 620
# merge: ('coun', 't')  vocab size: 621
# merge: ('cul', 'ture')  vocab size: 622
# merge: ('econom', 'y')  vocab size: 623
# merge: ('2', '1')  vocab size: 624
# merge: ('b', 'le')  vocab size: 625
# merge: ('m', 's')  vocab size: 626
# merge: ('it', 'ed')  vocab size: 627
# merge: ('k', 'a')  vocab size: 628
# merge: ('b', 'as')  vocab size: 629
# merge: ('soci', 'al')  vocab size: 630
# merge: ('t', 'y')  vocab size: 631
# merge: ('w', 'om')  vocab size: 632
# merge: ('man', 'y')  vocab size: 633
# merge: ('en', 'ti')  vocab size: 634
# merge: ('vi', 'd')  vocab size: 635
# merge: ('ac', 'k')  vocab size: 636
# merge: ('e', 'f')  vocab size: 637
# merge: ('es', 's')  vocab size: 638
# merge: ('201', '7')  vocab size: 639
# merge: ('d', 'ance')  vocab size: 640
# merge: ('m', 'ber')  vocab size: 641
# merge: ('en', 'cy')  vocab size: 642
# merge: ('ct', 'ed')  vocab size: 643
# merge: ('y', 'a')  vocab size: 644
# merge: ('bo', 't')  vocab size: 645
# merge: ('a', 'i')  vocab size: 646
# merge: ('jan', 'u')  vocab size: 647
# merge: ('janu', 'ary')  vocab size: 647
# merge: ('ist', 'an')  vocab size: 648
# merge: ('v', 'il')  vocab size: 649
# merge: ('ro', 'pe')  vocab size: 650
# merge: ('be', 'came')  vocab size: 651
# merge: ('mil', 'lion')  vocab size: 652
# merge: ('on', 'd')  vocab size: 653
# merge: ('per', 'i')  vocab size: 654
# merge: ('su', 'ch')  vocab size: 655
# merge: ('j', 'o')  vocab size: 656
# merge: ('o', 'p')  vocab size: 657
# merge: ('p', 'a')  vocab size: 658
# merge: ('por', 't')  vocab size: 659
# merge: ('artic', 'le')  vocab size: 660
# merge: ('b', 'l')  vocab size: 661
# merge: ('st', 'ate')  vocab size: 662
# merge: ('h', 'indi')  vocab size: 663
# merge: ('relig', 'ion')  vocab size: 664
# merge: ('am', 'ent')  vocab size: 665
# merge: ('minist', 'er')  vocab size: 666
# merge: ('6', '9')  vocab size: 667
# merge: ('world', 's')  vocab size: 668
# merge: ('nor', 'th')  vocab size: 669
# merge: ('b', 'ar')  vocab size: 670
# merge: ('hu', 'man')  vocab size: 671
# merge: ('l', 'ater')  vocab size: 672
# merge: ('in', 's')  vocab size: 673
# merge: ('v', 'ing')  vocab size: 674
# merge: ('cent', 'ral')  vocab size: 675
# merge: ('ul', 't')  vocab size: 676
# merge: ('gro', 'w')  vocab size: 677
# merge: ('ou', 'gh')  vocab size: 678
# merge: ('b', 'u')  vocab size: 679
# merge: ('le', 'ar')  vocab size: 680
# merge: ('te', 'x')  vocab size: 681
# merge: ('at', 'u')  vocab size: 682
# merge: ('empi', 're')  vocab size: 683
# merge: ('ang', 'es')  vocab size: 684
# merge: ('n', 'on')  vocab size: 685
# merge: ('p', 'ut')  vocab size: 686
# merge: ('ol', 'd')  vocab size: 687
# merge: ('the', 'se')  vocab size: 688
# merge: ('ur', 'ban')  vocab size: 689
# merge: ('c', 'an')  vocab size: 690
# merge: ('201', '6')  vocab size: 691
# merge: ('led', 'ge')  vocab size: 692
# merge: ('c', 'lo')  vocab size: 693
# merge: ('e', 'w')  vocab size: 694
# merge: ('ar', 't')  vocab size: 695
# merge: ('pri', 'me')  vocab size: 696
# merge: ('ti', 'me')  vocab size: 697
# merge: ('l', 'ing')  vocab size: 698
# merge: ('sub', 'continent')  vocab size: 699
# merge: ('v', 'ol')  vocab size: 700
# merge: ('eu', 'rope')  vocab size: 701
# merge: ('c', 'ord')  vocab size: 702
# merge: ('ma', 'j')  vocab size: 703
# merge: ('maj', 'or')  vocab size: 703
# merge: ('an', 'ci')  vocab size: 704
# merge: ('al', 's')  vocab size: 705
# merge: ('fore', 'st')  vocab size: 706
# merge: ('b', 'ro')  vocab size: 707
# merge: ('ab', 'le')  vocab size: 708
# merge: ('st', 'ates')  vocab size: 709
# merge: ('di', 'a')  vocab size: 710
# merge: ('v', 'es')  vocab size: 711
# merge: ('tr', 'ans')  vocab size: 712
# merge: ('og', 'ra')  vocab size: 713
# merge: ('ogra', 'ph')  vocab size: 713
# merge: ('re', 'public')  vocab size: 714
# merge: ('7', '7')  vocab size: 715
# merge: ('hindu', 'ism')  vocab size: 716
# merge: ('ens', 'us')  vocab size: 717
# merge: ('p', 'ak')  vocab size: 718
# merge: ('li', 'fe')  vocab size: 719
# merge: ('nor', 'thern')  vocab size: 720
# merge: ('3', '4')  vocab size: 721
# merge: ('wom', 'en')  vocab size: 722
# merge: ('li', 'm')  vocab size: 723
# merge: ('le', 'ft')  vocab size: 724
# merge: ('k', 'ash')  vocab size: 725
# merge: ('il', 'd')  vocab size: 726
# merge: ('class', 'ical')  vocab size: 727
# merge: ('f', 'ound')  vocab size: 728
# merge: ('o', 's')  vocab size: 729
# merge: ('an', 'a')  vocab size: 730
# merge: ('pl', 'ay')  vocab size: 731
# merge: ('201', '5')  vocab size: 732
# merge: ('ash', 'er')  vocab size: 733
# merge: ('d', 'ay')  vocab size: 734
# merge: ('the', 'm')  vocab size: 735
# merge: ('eng', 'lish')  vocab size: 736
# merge: ('c', 'ensus')  vocab size: 737
# merge: ('se', 't')  vocab size: 738
# merge: ('er', 'g')  vocab size: 739
# merge: ('le', 'y')  vocab size: 740
# merge: ('d', 'ra')  vocab size: 741
# merge: ('ig', 'n')  vocab size: 742
# merge: ('19', '5')  vocab size: 743
# merge: ('an', 'n')  vocab size: 744
# merge: ('g', 'ar')  vocab size: 745
# merge: ('at', 'ing')  vocab size: 746
# merge: ('s', 'ci')  vocab size: 747
# merge: ('tam', 'il')  vocab size: 748
# merge: ('the', 'y')  vocab size: 749
# merge: ('mal', 'ay')  vocab size: 750
# merge: ('c', 'u')  vocab size: 751
# merge: ('ci', 'es')  vocab size: 752
# merge: ('un', 'ion')  vocab size: 753
# merge: ('200', '3')  vocab size: 754
# merge: ('20', '20')  vocab size: 755
# merge: ('ro', 'ut')  vocab size: 756
# merge: ('rout', 'ledge')  vocab size: 756
# merge: ('n', 'al')  vocab size: 757
# merge: ('count', 'ry')  vocab size: 758
# merge: ('r', 'on')  vocab size: 759
# merge: ('v', 'a')  vocab size: 760
# merge: ('c', 'ap')  vocab size: 761
# merge: ('ati', 've')  vocab size: 762
# merge: ('k', 'h')  vocab size: 763
# merge: ('v', 'ic')  vocab size: 764
# merge: ('19', '50')  vocab size: 765
# merge: ('pak', 'istan')  vocab size: 766
# merge: ('chin', 'a')  vocab size: 767
# merge: ('p', 'al')  vocab size: 768
# merge: ('d', 'a')  vocab size: 769
# merge: ('d', 'le')  vocab size: 770
# merge: ('u', 'ri')  vocab size: 771
# merge: ('wor', 'k')  vocab size: 772
# merge: ('p', 'un')  vocab size: 773
# merge: ('re', 'l')  vocab size: 774
# merge: ('ru', 'le')  vocab size: 775
# merge: ('te', 'ch')  vocab size: 776
# merge: ('anci', 'ent')  vocab size: 777
# merge: ('pro', 'du')  vocab size: 778
# merge: ('w', 'er')  vocab size: 779
# merge: ('ou', 'ld')  vocab size: 780
# merge: ('b', 'ra')  vocab size: 781
# merge: ('10', '0')  vocab size: 782
# merge: ('si', 'st')  vocab size: 783
# merge: ('is', 'sion')  vocab size: 784
# merge: ('asi', 'an')  vocab size: 785
# merge: ('su', 'm')  vocab size: 786
# merge: ('ction', 's')  vocab size: 787
# merge: ('pl', 'ate')  vocab size: 788
# merge: ('f', 'ish')  vocab size: 789
# merge: ('m', 'ember')  vocab size: 789
# merge: ('se', 'm')  vocab size: 790
# merge: ('an', 'i')  vocab size: 791
# merge: ('b', 'ru')  vocab size: 792
# merge: ('ste', 'in')  vocab size: 793
# merge: ('tal', 'bot')  vocab size: 794
# merge: ('f', 'ol')  vocab size: 795
# merge: ('no', 'w')  vocab size: 796
# merge: ('or', 'i')  vocab size: 797
# merge: ('d', 's')  vocab size: 798
# merge: ('pe', 'o')  vocab size: 799
# merge: ('se', 'con')  vocab size: 800
# merge: ('hi', 'gh')  vocab size: 801
# merge: ('ter', 'rit')  vocab size: 802
# merge: ('7', '9')  vocab size: 803
# merge: ('19', '47')  vocab size: 804
# merge: ('202', '2')  vocab size: 805
# merge: ('ind', 'us')  vocab size: 806
# merge: ('di', 'f')  vocab size: 807
# merge: ('su', 'pp')  vocab size: 808
# merge: ('4', '4')  vocab size: 809
# merge: ('4', '5')  vocab size: 810
# merge: ('be', 'gan')  vocab size: 811
# merge: ('fl', 'u')  vocab size: 812
# merge: ('ment', 's')  vocab size: 813
# merge: ('l', 'it')  vocab size: 814
# merge: ('n', 'uc')  vocab size: 815
# merge: ('nuc', 'lear')  vocab size: 815
# merge: ('ter', 'm')  vocab size: 816
# merge: ('bo', 'th')  vocab size: 817
# merge: ('peri', 'od')  vocab size: 818
# merge: ('pos', 'ed')  vocab size: 819
# merge: ('f', 'am')  vocab size: 820
# merge: ('po', 'wer')  vocab size: 821
# merge: ('tion', 's')  vocab size: 822
# merge: ('st', 'r')  vocab size: 823
# merge: ('f', 'a')  vocab size: 824
# merge: ('gen', 'eral')  vocab size: 825
# merge: ('mar', 'k')  vocab size: 826
# merge: ('200', '4')  vocab size: 827
# merge: ('200', '1')  vocab size: 828
# merge: ('199', '4')  vocab size: 829
# merge: ('fe', 'bru')  vocab size: 830
# merge: ('febru', 'ary')  vocab size: 830
# merge: ('de', 'mo')  vocab size: 831
# merge: ('le', 'g')  vocab size: 832
# merge: ('ra', 'j')  vocab size: 833
# merge: ('p', 'end')  vocab size: 834
# merge: ('un', 'ited')  vocab size: 835
# merge: ('to', 'tal')  vocab size: 836
# merge: ('8', '5')  vocab size: 837
# merge: ('s', 'ince')  vocab size: 838
# merge: ('b', 'eng')  vocab size: 839
# merge: ('ma', 'de')  vocab size: 840
# merge: ('is', 'ation')  vocab size: 841
# merge: ('ir', 'd')  vocab size: 842
# merge: ('poli', 'tical')  vocab size: 843
# merge: ('ar', 'a')  vocab size: 844
# merge: ('pun', 'j')  vocab size: 845
# merge: ('punj', 'ab')  vocab size: 845
# merge: ('lit', 'er')  vocab size: 846
# merge: ('di', 'versity')  vocab size: 847
# merge: ('east', 'ern')  vocab size: 848
# merge: ('l', 'ine')  vocab size: 849
# merge: ('incl', 'ud')  vocab size: 850
# merge: ('lo', 'y')  vocab size: 851
# merge: ('di', 'c')  vocab size: 852
# merge: ('ch', 'an')  vocab size: 853
# merge: ('gro', 'up')  vocab size: 854
# merge: ('ri', 'ght')  vocab size: 855
# merge: ('6', '0')  vocab size: 856
# merge: ('201', '3')  vocab size: 857
# merge: ('y', 'or')  vocab size: 858
# merge: ('d', 'an')  vocab size: 859
# merge: ('9780', '5')  vocab size: 860
# merge: ('978', '8')  vocab size: 861
# merge: ('g', 'o')  vocab size: 862
# merge: ('et', 'y')  vocab size: 863
# merge: ('vi', 'ew')  vocab size: 864
# merge: ('g', 'lo')  vocab size: 865
# merge: ('b', 'h')  vocab size: 866
# merge: ('peo', 'ple')  vocab size: 867
# merge: ('del', 'hi')  vocab size: 868
# merge: ('is', 'ed')  vocab size: 869
# merge: ('202', '5')  vocab size: 870
# merge: ('sh', 'ar')  vocab size: 871
# merge: ('b', 'or')  vocab size: 872
# merge: ('l', 'en')  vocab size: 873
# merge: ('in', 'do')  vocab size: 874
# merge: ('pl', 'ain')  vocab size: 875
# merge: ('in', 'tro')  vocab size: 876
# merge: ('intro', 'du')  vocab size: 876
# merge: ('b', 'il')  vocab size: 877
# merge: ('bi', 'o')  vocab size: 878
# merge: ('ate', 'ly')  vocab size: 879
# merge: ('de', 'f')  vocab size: 880
# merge: ('pres', 'ent')  vocab size: 881
# merge: ('on', 'ly')  vocab size: 882
# merge: ('wh', 'en')  vocab size: 883
# merge: ('8', '7')  vocab size: 884
# merge: ('wh', 'ere')  vocab size: 885
# merge: ('develop', 'ment')  vocab size: 886
# merge: ('t', 'emp')  vocab size: 887
# merge: ('m', 'er')  vocab size: 888
# merge: ('le', 'ad')  vocab size: 889
# merge: ('c', 'ar')  vocab size: 890
# merge: ('be', 'fore')  vocab size: 891
# merge: ('t', 'on')  vocab size: 892
# merge: ('ro', 'w')  vocab size: 893
# merge: ('m', 'arch')  vocab size: 894
# merge: ('jo', 'h')  vocab size: 895
# merge: ('bo', 'ok')  vocab size: 896
# merge: ('k', 'i')  vocab size: 897
# merge: ('wi', 'de')  vocab size: 898
# merge: ('land', 's')  vocab size: 899
# merge: ('ri', 'ver')  vocab size: 900
# merge: ('h', 'y')  vocab size: 901
# merge: ('or', 'gan')  vocab size: 902
# merge: ('mid', 'dle')  vocab size: 903
# merge: ('j', 'e')  vocab size: 904
# merge: ('4', '6')  vocab size: 905
# merge: ('we', 'll')  vocab size: 906
# merge: ('i', 'li')  vocab size: 907
# merge: ('h', 'is')  vocab size: 908
# merge: ('at', 'ter')  vocab size: 909
# merge: ('er', 'ing')  vocab size: 910
# merge: ('f', 'ar')  vocab size: 911
# merge: ('ch', 'e')  vocab size: 912
# merge: ('si', 'g')  vocab size: 913
# merge: ('l', 'a')  vocab size: 914
# merge: ('hi', 'malay')  vocab size: 915
# merge: ('c', 'our')  vocab size: 916
# merge: ('c', 'is')  vocab size: 917
# merge: ('inter', 'national')  vocab size: 918
# merge: ('ct', 'or')  vocab size: 919
# merge: ('s', 'hi')  vocab size: 920
# merge: ('mathema', 'tics')  vocab size: 921
# merge: ('dy', 'son')  vocab size: 922
# merge: ('ent', 's')  vocab size: 923
# merge: ('ge', 'ograph')  vocab size: 924
# merge: ('ex', 't')  vocab size: 925
# merge: ('e', 'i')  vocab size: 926
# merge: ('is', 'l')  vocab size: 927
# merge: ('par', 'li')  vocab size: 928
# merge: ('parli', 'ament')  vocab size: 928
# merge: ('m', 'y')  vocab size: 929
# merge: ('b', 'ang')  vocab size: 930
# merge: ('ag', 'o')  vocab size: 931
# merge: ('ci', 'vil')  vocab size: 932
# merge: ('ear', 'ly')  vocab size: 933
# merge: ('l', 'ast')  vocab size: 934
# merge: ('mu', 'gh')  vocab size: 935
# merge: ('tech', 'n')  vocab size: 936
# merge: ('in', 'flu')  vocab size: 937
# merge: ('s', 's')  vocab size: 938
# merge: ('th', 'ro')  vocab size: 939
# merge: ('p', 'en')  vocab size: 940
# merge: ('secon', 'd')  vocab size: 941
# merge: ('ir', 'on')  vocab size: 942
# merge: ('st', 'ru')  vocab size: 943
# merge: ('er', 't')  vocab size: 944
# merge: ('sci', 'ence')  vocab size: 945
# merge: ('se', 'ver')  vocab size: 946
# merge: ('p', 'i')  vocab size: 947
# merge: ('pra', 'c')  vocab size: 948
# merge: ('a', 'th')  vocab size: 949
# merge: ('j', 'am')  vocab size: 950
# merge: ('hin', 'd')  vocab size: 951
# merge: ('er', 'ed')  vocab size: 952
# merge: ('h', 'and')  vocab size: 953
# merge: ('ch', 'and')  vocab size: 954
# merge: ('vis', 'ion')  vocab size: 955
# merge: ('eng', 'ine')  vocab size: 956
# merge: ('ge', 't')  vocab size: 957
# merge: ('200', '5')  vocab size: 958
# merge: ('b', 'b')  vocab size: 959
# merge: ('pe', 'dia')  vocab size: 960
# merge: ('se', 'e')  vocab size: 961
# merge: ('g', 'a')  vocab size: 962
# merge: ('ra', 'tion')  vocab size: 963
# merge: ('ro', 'l')  vocab size: 964
# merge: ('j', 'ain')  vocab size: 965
# merge: ('n', 'ar')  vocab size: 966
# merge: ('de', 'pend')  vocab size: 967
# merge: ('dom', 'in')  vocab size: 968
# merge: ('n', 'd')  vocab size: 969
# merge: ('demo', 'cra')  vocab size: 970
# merge: ('oc', 'c')  vocab size: 971
# merge: ('th', 'ird')  vocab size: 972
# merge: ('t', 'ur')  vocab size: 973
# merge: ('mo', 've')  vocab size: 974
# merge: ('u', 'gh')  vocab size: 975
# merge: ('kash', 'm')  vocab size: 976
# merge: ('kashm', 'ir')  vocab size: 976
# merge: ('cord', 'ing')  vocab size: 977
# merge: ('r', 'en')  vocab size: 978
# merge: ('st', 'y')  vocab size: 979
# merge: ('or', 'al')  vocab size: 980
# merge: ('g', 'anges')  vocab size: 981
# merge: ('emp', 'loy')  vocab size: 982
# merge: ('c', 'tive')  vocab size: 983
# merge: ('b', 'r')  vocab size: 984
# merge: ('ak', 'a')  vocab size: 985
# merge: ('i', 'i')  vocab size: 986
# merge: ('g', 'er')  vocab size: 987
# merge: ('g', 'and')  vocab size: 988
# merge: ('ne', 'h')  vocab size: 989
# merge: ('di', 're')  vocab size: 990
# merge: ('k', 'u')  vocab size: 991
# merge: ('spe', 'cies')  vocab size: 992
# merge: ('d', 'en')  vocab size: 993
# merge: ('or', 't')  vocab size: 994
# merge: ('sem', 'b')  vocab size: 995
# merge: ('es', 'e')  vocab size: 996
# merge: ('s', 'ar')  vocab size: 997
# merge: ('glo', 'bal')  vocab size: 998
# merge: ('engine', 'ering')  vocab size: 999
# merge: ('mar', 'ri')  vocab size: 1000
# merge: ('no', 've')  vocab size: 1001
# merge: ('200', '0')  vocab size: 1002
# merge: ('qu', 'o')  vocab size: 1003
# merge: ('yor', 'k')  vocab size: 1004
# merge: ('par', 'ti')  vocab size: 1005
# merge: ('am', 'e')  vocab size: 1006
# merge: ('6', '5')  vocab size: 1007
# merge: ('in', 'i')  vocab size: 1008
# merge: ('ad', 'es')  vocab size: 1009
# merge: ('am', 'an')  vocab size: 1010
# merge: ('em', 'erg')  vocab size: 1011
# merge: ('europe', 'an')  vocab size: 1012
# merge: ('relig', 'i')  vocab size: 1012
# merge: ('m', 'it')  vocab size: 1013
# merge: ('mugh', 'al')  vocab size: 1014
# merge: ('ac', 'y')  vocab size: 1015
# merge: ('compan', 'y')  vocab size: 1016
# merge: ('n', 'ed')  vocab size: 1017
# merge: ('indian', 's')  vocab size: 1018
# merge: ('com', 'e')  vocab size: 1019
# merge: ('6', '7')  vocab size: 1020
# merge: ('b', 'har')  vocab size: 1021
# merge: ('7', '0')  vocab size: 1022
# merge: ('3', '00')  vocab size: 1023
# merge: ('includ', 'ing')  vocab size: 1024
# merge: ('ag', 'ri')  vocab size: 1025
# merge: ('en', 'v')  vocab size: 1026
# merge: ('env', 'iron')  vocab size: 1026
# merge: ('environ', 'ment')  vocab size: 1026
# merge: ('od', 's')  vocab size: 1027
# merge: ('ul', 'ar')  vocab size: 1028
# merge: ('budd', 'hist')  vocab size: 1029
# merge: ('alth', 'ough')  vocab size: 1030
# merge: ('gen', 'er')  vocab size: 1031
# merge: ('v', 'an')  vocab size: 1032
# merge: ('low', 'ing')  vocab size: 1033
# merge: ('gand', 'hi')  vocab size: 1034
# merge: ('o', 'per')  vocab size: 1035
# merge: ('or', 'ies')  vocab size: 1036
# merge: ('re', 'main')  vocab size: 1037
# merge: ('bl', 'ack')  vocab size: 1038
# merge: ('a', 'h')  vocab size: 1039
# merge: ('202', '4')  vocab size: 1040
# merge: ('as', 'semb')  vocab size: 1041
# merge: ('comm', 'on')  vocab size: 1042
# merge: ('f', 'und')  vocab size: 1043
# merge: ('man', 'i')  vocab size: 1044
# merge: ('tra', 'de')  vocab size: 1045
# merge: ('i', 'z')  vocab size: 1046
# merge: ('con', 'tri')  vocab size: 1047
# merge: ('de', 'ce')  vocab size: 1048
# merge: ('dece', 'mber')  vocab size: 1048
# merge: ('doi10', '10')  vocab size: 1049
# merge: ('wi', 'ki')  vocab size: 1050
# merge: ('sou', 'r')  vocab size: 1051
# merge: ('cent', 're')  vocab size: 1052
# merge: ('cont', 'rol')  vocab size: 1053
# merge: ('are', 'a')  vocab size: 1054
# merge: ('f', 'ed')  vocab size: 1055
# merge: ('2', 'nd')  vocab size: 1056
# merge: ('the', 'ast')  vocab size: 1057
# merge: ('5', '5')  vocab size: 1058
# merge: ('ing', 's')  vocab size: 1059
# merge: ('4', '00')  vocab size: 1060
# merge: ('o', 'se')  vocab size: 1061
# merge: ('c', 'ture')  vocab size: 1062
# merge: ('cent', 'uri')  vocab size: 1063
# merge: ('centuri', 'es')  vocab size: 1063
# merge: ('ult', 'an')  vocab size: 1064
# merge: ('a', 'ce')  vocab size: 1065
# merge: ('4', '8')  vocab size: 1066
# merge: ('p', 'and')  vocab size: 1067
# merge: ('ed', 'uc')  vocab size: 1068
# merge: ('is', 'tic')  vocab size: 1069
# merge: ('increas', 'ed')  vocab size: 1070
# merge: ('techn', 'ology')  vocab size: 1071
# merge: ('it', 'ary')  vocab size: 1072
# merge: ('f', 'our')  vocab size: 1073
# merge: ('at', 's')  vocab size: 1074
# merge: ('ac', 'cording')  vocab size: 1075
# merge: ('per', 'si')  vocab size: 1076
# merge: ('bas', 'ed')  vocab size: 1077
# merge: ('form', 's')  vocab size: 1078
# merge: ('ho', 'we')  vocab size: 1079
# merge: ('howe', 'ver')  vocab size: 1079
# merge: ('de', 'st')  vocab size: 1080
# merge: ('com', 'posed')  vocab size: 1081
# merge: ('ma', 'h')  vocab size: 1082
# merge: ('dif', 'fer')  vocab size: 1083
# merge: ('bra', 'h')  vocab size: 1084
# merge: ('tex', 'ts')  vocab size: 1085
# merge: ('spe', 'ak')  vocab size: 1086
# merge: ('ver', 'y')  vocab size: 1087
# merge: ('neh', 'ru')  vocab size: 1088
# merge: ('sur', 've')  vocab size: 1089
# merge: ('de', 'c')  vocab size: 1090
# merge: ('in', 'du')  vocab size: 1091
# merge: ('r', 'ural')  vocab size: 1092
# merge: ('p', 'ur')  vocab size: 1093
# merge: ('f', 'ul')  vocab size: 1094
# merge: ('al', 'e')  vocab size: 1095
# merge: ('part', 'y')  vocab size: 1096
# merge: ('assemb', 'ly')  vocab size: 1097
# merge: ('nation', 's')  vocab size: 1098
# merge: ('grow', 'th')  vocab size: 1099
# merge: ('g', 'i')  vocab size: 1100
# merge: ('li', 'st')  vocab size: 1101
# merge: ('o', 'ol')  vocab size: 1102
# merge: ('joh', 'n')  vocab size: 1103
# merge: ('97805', '2')  vocab size: 1104
# merge: ('nove', 'mber')  vocab size: 1104
# merge: ('quo', 'te')  vocab size: 1105
# merge: ('st', 'and')  vocab size: 1106
# merge: ('u', 'e')  vocab size: 1107
# merge: ('r', 'ul')  vocab size: 1108
# merge: ('r', 'ish')  vocab size: 1109
# merge: ('in', 'depend')  vocab size: 1110
# merge: ('6', '3')  vocab size: 1111
# merge: ('cur', 'r')  vocab size: 1112
# merge: ('0', '5')  vocab size: 1113
# merge: ('beng', 'al')  vocab size: 1114
# merge: ('der', 's')  vocab size: 1115
# merge: ('af', 'ri')  vocab size: 1116
# merge: ('mil', 'len')  vocab size: 1117
# merge: ('millen', 'ni')  vocab size: 1117
# merge: ('religi', 'ous')  vocab size: 1118
# merge: ('co', 'ast')  vocab size: 1119
# merge: ('ent', 'ly')  vocab size: 1120
# merge: ('c', 'ro')  vocab size: 1121
# merge: ('p', 'rom')  vocab size: 1122
# merge: ('educ', 'ation')  vocab size: 1123
# merge: ('move', 'ment')  vocab size: 1124
# merge: ('vi', 'ol')  vocab size: 1125
# merge: ('major', 'ity')  vocab size: 1126
# merge: ('thro', 'ugh')  vocab size: 1127
# merge: ('soci', 'ety')  vocab size: 1128
# merge: ('bil', 'lion')  vocab size: 1129
# merge: ('r', 'ate')  vocab size: 1130
# merge: ('l', 's')  vocab size: 1131
# merge: ('m', 'en')  vocab size: 1132
# merge: ('e', 'pic')  vocab size: 1133
# merge: ('nam', 'e')  vocab size: 1134
# merge: ('hindu', 'st')  vocab size: 1135
# merge: ('li', 'ke')  vocab size: 1136
# merge: ('at', 't')  vocab size: 1137
# merge: ('ri', 'g')  vocab size: 1138
# merge: ('ran', 'ge')  vocab size: 1139
# merge: ('di', 't')  vocab size: 1140
# merge: ('v', 'o')  vocab size: 1141
# merge: ('cul', 't')  vocab size: 1142
# merge: ('cult', 'ural')  vocab size: 1142
# merge: ('w', 'ay')  vocab size: 1143
# merge: ('o', 'w')  vocab size: 1144
# merge: ('temp', 'le')  vocab size: 1145
# merge: ('j', 'our')  vocab size: 1146
# merge: ('1', '10')  vocab size: 1147
# merge: ('b', 'ed')  vocab size: 1148
# merge: ('es', 'pe')  vocab size: 1149
# merge: ('espe', 'ci')  vocab size: 1149
# merge: ('especi', 'ally')  vocab size: 1149
# merge: ('ces', 's')  vocab size: 1150
# merge: ('comm', 'ission')  vocab size: 1151
# merge: ('introdu', 'ction')  vocab size: 1152
# merge: ('t', 're')  vocab size: 1153
# merge: ('indu', 'st')  vocab size: 1154
# merge: ('app', 'ro')  vocab size: 1155
# merge: ('oper', 'ation')  vocab size: 1156
# merge: ('u', 'de')  vocab size: 1157
# merge: ('chan', 'ge')  vocab size: 1158
# merge: ('pra', 'des')  vocab size: 1159
# merge: ('prades', 'h')  vocab size: 1159
# merge: ('n', 'ad')  vocab size: 1160
# merge: ('u', 'se')  vocab size: 1161
# merge: ('poli', 'cy')  vocab size: 1162
# merge: ('co', 'ok')  vocab size: 1163
# merge: ('197', '0')  vocab size: 1164
# merge: ('ve', 'dic')  vocab size: 1165
# merge: ('40', '2')  vocab size: 1166
# merge: ('minist', 'ry')  vocab size: 1167
# merge: ('199', '7')  vocab size: 1168
# merge: ('en', 'ces')  vocab size: 1169
# merge: ('b', 'ir')  vocab size: 1170
# merge: ('ab', 'out')  vocab size: 1171
# merge: ('ig', 'u')  vocab size: 1172
# merge: ('cap', 'it')  vocab size: 1173
# merge: ('p', 'ol')  vocab size: 1174
# merge: ('sch', 'ed')  vocab size: 1175
# merge: ('si', 'kh')  vocab size: 1176
# merge: ('pres', 'id')  vocab size: 1177
# merge: ('atu', 're')  vocab size: 1178
# merge: ('h', 'ou')  vocab size: 1179
# merge: ('es', 'tim')  vocab size: 1180
# merge: ('n', 'ic')  vocab size: 1181
# merge: ('afri', 'ca')  vocab size: 1182
# merge: ('occ', 'up')  vocab size: 1183
# merge: ('ver', 'se')  vocab size: 1184
# merge: ('millenni', 'um')  vocab size: 1185
# merge: ('ex', 'ist')  vocab size: 1186
# merge: ('with', 'in')  vocab size: 1187
# merge: ('h', 'ere')  vocab size: 1188
# merge: ('ris', 'e')  vocab size: 1189
# merge: ('arch', 'ite')  vocab size: 1190
# merge: ('st', 'at')  vocab size: 1191
# merge: ('de', 'cl')  vocab size: 1192
# merge: ('ab', 'il')  vocab size: 1193
# merge: ('s', 'ultan')  vocab size: 1194
# merge: ('in', 'stitu')  vocab size: 1195
# merge: ('col', 'on')  vocab size: 1196
# merge: ('i', 'de')  vocab size: 1197
# merge: ('e', 'th')  vocab size: 1198
# merge: ('liter', 'acy')  vocab size: 1199
# merge: ('mil', 'itary')  vocab size: 1200
# merge: ('l', 'u')  vocab size: 1201
# merge: ('persi', 'an')  vocab size: 1202
# merge: ('bhar', 'at')  vocab size: 1203
# merge: ('d', 'ata')  vocab size: 1204
# merge: ('ear', 'li')  vocab size: 1205
# merge: ('k', 'no')  vocab size: 1206
# merge: ('kno', 'wn')  vocab size: 1206
# merge: ('an', 'im')  vocab size: 1207
# merge: ('z', 'e')  vocab size: 1208
# merge: ('ch', 'ar')  vocab size: 1209
# merge: ('ved', 'a')  vocab size: 1210
# merge: ('ol', 'dest')  vocab size: 1211
# merge: ('wh', 'at')  vocab size: 1212
# merge: ('w', 'ould')  vocab size: 1213
# merge: ('si', 've')  vocab size: 1214
# merge: ('9', '3')  vocab size: 1215
# merge: ('al', 'ong')  vocab size: 1216
# merge: ('or', 's')  vocab size: 1217
# merge: ('in', 'es')  vocab size: 1218
# merge: ('v', 'ent')  vocab size: 1219
# merge: ('o', 'wn')  vocab size: 1220
# merge: ('s', 'a')  vocab size: 1221
# merge: ('kar', 'nat')  vocab size: 1222
# merge: ('karnat', 'aka')  vocab size: 1222
# merge: ('12', '6')  vocab size: 1223
# merge: ('fo', 'od')  vocab size: 1224
# merge: ('al', 'li')  vocab size: 1225
# merge: ('gu', 'j')  vocab size: 1226
# merge: ('7', '5')  vocab size: 1227
# merge: ('ak', 'e')  vocab size: 1228
# merge: ('at', 'en')  vocab size: 1229
# merge: ('f', 'em')  vocab size: 1230
# merge: ('j', 'p')  vocab size: 1231
# merge: ('ele', 'ction')  vocab size: 1232
# merge: ('th', 'ree')  vocab size: 1233
# merge: ('di', 'es')  vocab size: 1234
# merge: ('nad', 'u')  vocab size: 1235
# merge: ('ad', 'dition')  vocab size: 1236
# merge: ('o', 're')  vocab size: 1237
# merge: ('st', 'ud')  vocab size: 1238
# merge: ('sch', 'ool')  vocab size: 1239
# merge: ('col', 'le')  vocab size: 1240
# merge: ('as', 'e')  vocab size: 1241
# merge: ('ra', 'm')  vocab size: 1242
# merge: ('pr', 'ince')  vocab size: 1243
# merge: ('ser', 'ies')  vocab size: 1244
# merge: ('u', 'k')  vocab size: 1245
# merge: ('v', 'in')  vocab size: 1246
# merge: ('978', '13')  vocab size: 1247
# merge: ('fish', 'er')  vocab size: 1248
# merge: ('er', 'ic')  vocab size: 1249
# merge: ('ber', 'g')  vocab size: 1250
# merge: ('se', 'arch')  vocab size: 1251
# merge: ('gra', 'ph')  vocab size: 1252
# merge: ('lo', 'cal')  vocab size: 1253
# merge: ('re', 'fer')  vocab size: 1254
# merge: ('m', 'all')  vocab size: 1255
# merge: ('k', 'es')  vocab size: 1256
# merge: ('4', '2')  vocab size: 1257
# merge: ('parliament', 'ary')  vocab size: 1258
# merge: ('presid', 'ent')  vocab size: 1259
# merge: ('u', 'pp')  vocab size: 1260
# merge: ('upp', 'er')  vocab size: 1260
# merge: ('ar', 'ab')  vocab size: 1261
# merge: ('i', 'an')  vocab size: 1262
# merge: ('ne', 'ar')  vocab size: 1263
# merge: ('l', 'an')  vocab size: 1264
# merge: ('on', 'es')  vocab size: 1265
# merge: ('region', 's')  vocab size: 1266
# merge: ('w', 'rit')  vocab size: 1267
# merge: ('in', 'ed')  vocab size: 1268
# merge: ('abil', 'ity')  vocab size: 1269
# merge: ('ex', 'por')  vocab size: 1270
# merge: ('est', 'ab')  vocab size: 1271
# merge: ('estab', 'lish')  vocab size: 1271
# merge: ('4', '3')  vocab size: 1272
# merge: ('medi', 'e')  vocab size: 1273
# merge: ('medie', 'val')  vocab size: 1273
# merge: ('18', '5')  vocab size: 1274
# merge: ('f', 'act')  vocab size: 1275
# merge: ('m', 'ig')  vocab size: 1276
# merge: ('ling', 'u')  vocab size: 1277
# merge: ('be', 'come')  vocab size: 1278
# merge: ('for', 'ma')  vocab size: 1279
# merge: ('th', 'ough')  vocab size: 1280
# merge: ('w', 'ild')  vocab size: 1281
# merge: ('popul', 'ar')  vocab size: 1282
# merge: ('p', 'ass')  vocab size: 1283
# merge: ('vil', 'l')  vocab size: 1283
# merge: ('t', 'ing')  vocab size: 1284
# merge: ('8', '0')  vocab size: 1285
# merge: ('fam', 'ili')  vocab size: 1286
# merge: ('v', 'ar')  vocab size: 1287
# merge: ('k', 'il')  vocab size: 1288
# merge: ('tu', 'al')  vocab size: 1289
# merge: ('sever', 'al')  vocab size: 1290
# merge: ('ro', 'ck')  vocab size: 1291
# merge: ('con', 'sist')  vocab size: 1292
# merge: ('pl', 'es')  vocab size: 1293
# merge: ('p', 'hi')  vocab size: 1294
# merge: ('l', 'aw')  vocab size: 1295
# merge: ('il', 't')  vocab size: 1296
# merge: ('h', 'am')  vocab size: 1297
# merge: ('t', 'ain')  vocab size: 1298
# merge: ('ci', 'al')  vocab size: 1299
# merge: ('af', 'fa')  vocab size: 1300
# merge: ('affa', 'ir')  vocab size: 1300
# merge: ('affair', 's')  vocab size: 1300
# merge: ('in', 't')  vocab size: 1301
# merge: ('of', 'f')  vocab size: 1302
# merge: ('dire', 'ct')  vocab size: 1303
# merge: ('fol', 'lowing')  vocab size: 1304
# merge: ('ser', 'ved')  vocab size: 1305
# merge: ('himalay', 'as')  vocab size: 1306
# merge: ('guj', 'ar')  vocab size: 1307
# merge: ('incl', 'ude')  vocab size: 1308
# merge: ('brah', 'ma')  vocab size: 1309
# merge: ('di', 'st')  vocab size: 1310
# merge: ('ro', 'und')  vocab size: 1311
# merge: ('m', 'ang')  vocab size: 1312
# merge: ('coun', 'tri')  vocab size: 1313
# merge: ('countri', 'es')  vocab size: 1313
# merge: ('n', 'er')  vocab size: 1314
# merge: ('t', 'ar')  vocab size: 1315
# merge: ('ma', 'd')  vocab size: 1316
# merge: ('199', '6')  vocab size: 1317
# merge: ('ch', 'ang')  vocab size: 1318
# merge: ('fore', 'ign')  vocab size: 1319
# merge: ('constitution', 'al')  vocab size: 1320
# merge: ('chin', 'ese')  vocab size: 1321
# merge: ('196', '0')  vocab size: 1322
# merge: ('iz', 'ation')  vocab size: 1323
# merge: ('se', 'ctor')  vocab size: 1324
# merge: ('m', 'ed')  vocab size: 1325
# merge: ('b', 'ur')  vocab size: 1326
# merge: ('da', 'vid')  vocab size: 1327
# merge: ('colle', 'ge')  vocab size: 1328
# merge: ('k', 'sh')  vocab size: 1329
# merge: ('a', 'e')  vocab size: 1330
# merge: ('200', '2')  vocab size: 1331
# merge: ('pub', 'lish')  vocab size: 1332
# merge: ('978', '14')  vocab size: 1333
# merge: ('e', 'ven')  vocab size: 1334
# merge: ('l', 'udd')  vocab size: 1335
# merge: ('ludd', 'en')  vocab size: 1335
# merge: ('jour', 'nal')  vocab size: 1336
# merge: ('shar', 'ma')  vocab size: 1337
# merge: ('ency', 'clo')  vocab size: 1338
# merge: ('encyclo', 'pedia')  vocab size: 1338
# merge: ('poli', 'tics')  vocab size: 1339
# merge: ('k', 's')  vocab size: 1340
# merge: ('pro', 'te')  vocab size: 1341
# merge: ('e', 'p')  vocab size: 1342
# merge: ('territ', 'ory')  vocab size: 1343
# merge: ('c', 'ity')  vocab size: 1344
# merge: ('re', 'c')  vocab size: 1345
# merge: ('isl', 'am')  vocab size: 1346
# merge: ('other', 's')  vocab size: 1347
# merge: ('fed', 'eral')  vocab size: 1348
# merge: ('hou', 'se')  vocab size: 1349
# merge: ('low', 'er')  vocab size: 1350
# merge: ('independ', 'ence')  vocab size: 1351
# merge: ('g', 'd')  vocab size: 1352
# merge: ('gd', 'p')  vocab size: 1352
# merge: ('13', '2')  vocab size: 1353
# merge: ('ne', 't')  vocab size: 1354
# merge: ('democra', 'cy')  vocab size: 1355
# merge: ('s', 'ri')  vocab size: 1356
# merge: ('and', 'aman')  vocab size: 1357
# merge: ('i', 'a')  vocab size: 1358
# merge: ('00', '0')  vocab size: 1359
# merge: ('emerg', 'ed')  vocab size: 1360
# merge: ('g', 'up')  vocab size: 1361
# merge: ('archite', 'cture')  vocab size: 1362
# merge: ('stat', 'us')  vocab size: 1363
# merge: ('li', 'e')  vocab size: 1364
# merge: ('m', 'ul')  vocab size: 1365
# merge: ('mul', 'ti')  vocab size: 1365
# merge: ('u', 'ally')  vocab size: 1366
# merge: ('grow', 'ing')  vocab size: 1367
# merge: ('dis', 'put')  vocab size: 1368
# merge: ('di', 'ction')  vocab size: 1369
# merge: ('wide', 'ly')  vocab size: 1370
# merge: ('produ', 'c')  vocab size: 1371
# merge: ('ar', 'ound')  vocab size: 1372
# merge: ('f', 'igu')  vocab size: 1373
# merge: ('to', 'day')  vocab size: 1374
# merge: ('ac', 'ro')  vocab size: 1375
# merge: ('acro', 'ss')  vocab size: 1375
# merge: ('agri', 'culture')  vocab size: 1376
# merge: ('reg', 'ist')  vocab size: 1377
# merge: ('religion', 's')  vocab size: 1378
# merge: ('a', 'de')  vocab size: 1379
# merge: ('com', 'ple')  vocab size: 1380
# merge: ('ch', 'ol')  vocab size: 1381
# merge: ('ac', 'tion')  vocab size: 1382
# merge: ('d', 'ed')  vocab size: 1383
# merge: ('9', '8')  vocab size: 1384
# merge: ('we', 'alth')  vocab size: 1385
# merge: ('tradition', 'al')  vocab size: 1386
# merge: ('number', 's')  vocab size: 1387
# merge: ('n', 'ing')  vocab size: 1388
# merge: ('indi', 'gen')  vocab size: 1389
# merge: ('indigen', 'ous')  vocab size: 1389
# merge: ('bu', 'ilt')  vocab size: 1390
# merge: ('g', 'old')  vocab size: 1391
# merge: ('o', 'b')  vocab size: 1392
# merge: ('w', 'il')  vocab size: 1393
# merge: ('prac', 'tic')  vocab size: 1394
# merge: ('practic', 'es')  vocab size: 1394
# merge: ('p', 'ain')  vocab size: 1395
# merge: ('12', '3')  vocab size: 1396
# merge: ('group', 's')  vocab size: 1397
# merge: ('long', 'er')  vocab size: 1398
# merge: ('indust', 'ry')  vocab size: 1399
# merge: ('x', 'im')  vocab size: 1400
# merge: ('co', 'operation')  vocab size: 1401
# merge: ('k', 'rish')  vocab size: 1402
# merge: ('ak', 'sh')  vocab size: 1403
# merge: ('1', '78')  vocab size: 1404
# merge: ('t', 'ree')  vocab size: 1405
# merge: ('of', 'ten')  vocab size: 1406
# merge: ('8', '6')  vocab size: 1407
# merge: ('de', 'ci')  vocab size: 1408
# merge: ('are', 'as')  vocab size: 1409
# merge: ('te', 'en')  vocab size: 1410
# merge: ('k', 'eral')  vocab size: 1411
# merge: ('fem', 'ale')  vocab size: 1412
# merge: ('b', 'jp')  vocab size: 1413
# merge: ('offic', 'e')  vocab size: 1414
# merge: ('ti', 'l')  vocab size: 1415
# merge: ('sing', 'h')  vocab size: 1416
# merge: ('bo', 'dy')  vocab size: 1417
# merge: ('3', '1')  vocab size: 1418
# merge: ('ju', 'st')  vocab size: 1419
# merge: ('ber', 't')  vocab size: 1420
# merge: ('fund', 'ament')  vocab size: 1420
# merge: ('ch', 'i')  vocab size: 1421
# merge: ('ti', 'ce')  vocab size: 1422
# merge: ('mark', 'et')  vocab size: 1423
# merge: ('is', 'e')  vocab size: 1424
# merge: ('famili', 'es')  vocab size: 1425
# merge: ('199', '2')  vocab size: 1426
# merge: ('hind', 'us')  vocab size: 1427
# merge: ('ch', 'a')  vocab size: 1428
# merge: ('s', 'it')  vocab size: 1429
# merge: ('dan', 'ces')  vocab size: 1430
# merge: ('th', 'ak')  vocab size: 1431
# merge: ('st', 'u')  vocab size: 1432
# merge: ('l', 'ond')  vocab size: 1433
# merge: ('lond', 'on')  vocab size: 1433
# merge: ('ro', 'bb')  vocab size: 1434
# merge: ('cra', 'ven')  vocab size: 1435
# merge: ('har', 'le')  vocab size: 1436
# merge: ('ic', 's')  vocab size: 1437
# merge: ('bir', 'th')  vocab size: 1438
# merge: ('s', 'mall')  vocab size: 1439
# merge: ('b', 'and')  vocab size: 1440
# merge: ('at', 'y')  vocab size: 1441
# merge: ('rec', 'og')  vocab size: 1442
# merge: ('region', 'al')  vocab size: 1443
# merge: ('le', 've')  vocab size: 1444
# merge: ('ei', 'gh')  vocab size: 1445
# merge: ('ch', 'ris')  vocab size: 1446
# merge: ('chris', 'ti')  vocab size: 1446
# merge: ('d', 'ro')  vocab size: 1447
# merge: ('up', 'a')  vocab size: 1448
# merge: ('9', '6')  vocab size: 1449
# merge: ('increas', 'e')  vocab size: 1450
# merge: ('po', 'si')  vocab size: 1451
# merge: ('qu', 'al')  vocab size: 1452
# merge: ('bang', 'l')  vocab size: 1453
# merge: ('bangl', 'ades')  vocab size: 1453
# merge: ('banglades', 'h')  vocab size: 1453
# merge: ('gra', 'du')  vocab size: 1454
# merge: ('val', 'ley')  vocab size: 1455
# merge: ('gup', 'ta')  vocab size: 1456
# merge: ('u', 'ch')  vocab size: 1457
# merge: ('tu', 'res')  vocab size: 1458
# merge: ('sultan', 'ate')  vocab size: 1459
# merge: ('ex', 'pand')  vocab size: 1460
# merge: ('olog', 'ical')  vocab size: 1461
# merge: ('o', 't')  vocab size: 1462
# merge: ('5', '7')  vocab size: 1463
# merge: ('ion', 's')  vocab size: 1464
# merge: ('f', 'ast')  vocab size: 1465
# merge: ('in', 'forma')  vocab size: 1466
# merge: ('ser', 'vic')  vocab size: 1467
# merge: ('ch', 'ild')  vocab size: 1468
# merge: ('bio', 'diversity')  vocab size: 1469
# merge: ('g', 'ree')  vocab size: 1470
# merge: ('6', '8')  vocab size: 1471
# merge: ('earli', 'est')  vocab size: 1472
# merge: ('5', '00')  vocab size: 1473
# merge: ('h', 'um')  vocab size: 1474
# merge: ('h', 'en')  vocab size: 1475
# merge: ('atu', 'res')  vocab size: 1476
# merge: ('writ', 'ten')  vocab size: 1477
# merge: ('cri', 'pt')  vocab size: 1478
# merge: ('be', 'ing')  vocab size: 1479
# merge: ('re', 'f')  vocab size: 1480
# merge: ('ter', 's')  vocab size: 1481
# merge: ('forest', 's')  vocab size: 1482
# merge: ('f', 'low')  vocab size: 1483
# merge: ('9', '5')  vocab size: 1484
# merge: ('pen', 'ins')  vocab size: 1485
# merge: ('ser', 'v')  vocab size: 1486
# merge: ('fi', 've')  vocab size: 1487
# merge: ('mu', 'ch')  vocab size: 1488
# merge: ('who', 'se')  vocab size: 1489
# merge: ('p', 'at')  vocab size: 1490
# merge: ('sig', 'ni')  vocab size: 1491
