# %%
def clean(text):
    texts=''
    for ch in text:
        if ch.isalnum() or ch==' ':
            texts+=ch.lower()
    return texts

# %%
def ch_token(text):
    clean_text=clean(text)
    ch_text=[]
    for ch in clean_text:
        if ch!=' ':
            ch_text.append(ch)
        else:
            ch_text.append('</w>')
    return ch_text

# %%
def count_pair(text):
    ch_tokens=ch_token(text)
    Dcount_pair={}
    for i in range(0,len(ch_tokens)-1):
        if ch_tokens[i]=='</w>':
            continue
        pair=(ch_tokens[i],ch_tokens[i+1])
        if '</w>' not in pair:
            if pair not in Dcount_pair:
                Dcount_pair[pair]=1
            else:
                Dcount_pair[pair]+=1
    return Dcount_pair

# %%
'''def merge_frequent_pair(text):
    count_pairs=count_pair(text)
    pairs=list(count_pairs.keys())
    print(pairs)
    merge_ch={}
    for i in count_pairs:
        if count_pairs[i]!=1:
            #print(i,"    ",count_pairs[i])
            merge=''
            #print(pairs[i])
            for j in range(0,len(pairs[i])):
                merge+=pairs[i][j]
                print(j,"   ",merge)
            merge_ch[merge]=1
        else:
            continue
    return merge_ch

# %%
'''def merge_frequent_pair(text):
    count_pairs=count_pair(text)
    pairs=list(count_pairs.keys())
    print(pairs)
    merge_ch={}
    for i in count_pairs:
        if count_pairs[i]!=1:
            #print(i,"    ",count_pairs[i])
            merge=''
            #print(pairs[i])
            for j in range(len(i)):
                merge+=i[j]
                print(j,"   ",merge)
            merge_ch[merge]=1
        else:
            continue
    return merge_ch
    '''
# this code updates all pair which effects the merging process

# %%
def best_pair(text):
    pair_count=ch_token(text)
    max_count=0
    best=None
    for pair in pair_count:
        if pair_count[pair]>max_count:
            best=pair
    return best

# %%
'''def merge_pair(tokens,pair):
    new_tokens=[]
    i=0
    while i<len(tokens):
        if i<len(tokens)-1 and tokens[i]==pair[0] and tokens[i+1]==pair[1]:
            merged=tokens[i]+tokens[i+1]

# %%
def merge_best_pair(text):
    pair=best_pair(text)
    new

# %%
text_in=input('enter the web text')
pair=best_pair(text_in)
count=merge_best_pair(text_in)
print(count)
# Out:
# enter the web textimport psutil import time import csv import os import platform import hashlib import json from datetime import datetime  # Optional GPU (NVIDIA) try:     import pynvml     pynvml.nvmlInit()     GPU_AVAILABLE = True except:     GPU_AVAILABLE = False  BASE_DIR = "system_monitor" DATA_DIR = os.path.join(BASE_DIR, "data") os.makedirs(DATA_DIR, exist_ok=True)  SYSTEM_FILE = os.path.join(DATA_DIR, "system_metrics.csv") PROCESS_FILE = os.path.join(DATA_DIR, "process_metrics.csv") GPU_FILE = os.path.join(DATA_DIR, "gpu_metrics.csv")  SYSTEM_INTERVAL = 5      # seconds PROCESS_INTERVAL = 30    # seconds TOP_N_PROCESSES = 5  # ------------------ UTILS ------------------  def get_machine_id():     raw = platform.node() + platform.processor()     return hashlib.sha256(raw.encode()).hexdigest()[:12]  MACHINE_ID = get_machine_id()  def timestamp():     return datetime.utcnow().isoformat()  # ------------------ META INFO ------------------  META_FILE = os.path.join(BASE_DIR, "machine_meta.json") if not os.path.exists(META_FILE):     meta = {         "machine_id": MACHINE_ID,         "os": platform.system(),         "os_version": platform.version(),         "cpu": platform.processor(),         "ram_gb": round(psutil.virtual_memory().total / (1024**3), 2)     }     with open(META_FILE, "w") as f:         json.dump(meta, f, indent=4)  # ------------------ CSV INIT ------------------  def init_csv(file, header):     if not os.path.exists(file):         with open(file, "w", newline="") as f:             writer = csv.writer(f)             writer.writerow(header)  init_csv(SYSTEM_FILE, [     "timestamp", "machine_id",     "cpu_percent", "load_1m",     "mem_used_percent",     "disk_read_kbps", "disk_write_kbps",     "net_in_kbps", "net_out_kbps",     "battery_percent", "power_plugged" ])  init_csv(PROCESS_FILE, [     "timestamp", "machine_id",     "process_name", "cpu_percent", "mem_percent" ])  init_csv(GPU_FILE, [     "timestamp", "machine_id",     "gpu_util_percent", "gpu_mem_used_mb", "gpu_temp_c" ])  # ------------------ METRIC COLLECTION ------------------  def collect_system_metrics():     cpu = psutil.cpu_percent()     load = psutil.getloadavg()[0] if hasattr(psutil, "getloadavg") else 0     mem = psutil.virtual_memory().percent      disk = psutil.disk_io_counters()     disk_read = disk.read_bytes / 1024     disk_write = disk.write_bytes / 1024      net = psutil.net_io_counters()     net_in = net.bytes_recv / 1024     net_out = net.bytes_sent / 1024      battery = psutil.sensors_battery()     battery_percent = battery.percent if battery else None     plugged = battery.power_plugged if battery else None      with open(SYSTEM_FILE, "a", newline="") as f:         writer = csv.writer(f)         writer.writerow([             timestamp(), MACHINE_ID,             cpu, load, mem,             disk_read, disk_write,             net_in, net_out,             battery_percent, plugged         ])  def collect_process_metrics():     processes = []     for p in psutil.process_iter(['name', 'cpu_percent', 'memory_percent']):         try:             processes.append(p.info)         except:             pass      top = sorted(processes, key=lambda x: x['cpu_percent'], reverse=True)[:TOP_N_PROCESSES]      with open(PROCESS_FILE, "a", newline="") as f:         writer = csv.writer(f)         for p in top:             writer.writerow([                 timestamp(), MACHINE_ID,                 p['name'], p['cpu_percent'], p['memory_percent']             ])  def collect_gpu_metrics():     if not GPU_AVAILABLE:         return      try:         handle = pynvml.nvmlDeviceGetHandleByIndex(0)         util = pynvml.nvmlDeviceGetUtilizationRates(handle)         mem = pynvml.nvmlDeviceGetMemoryInfo(handle)         temp = pynvml.nvmlDeviceGetTemperature(handle, pynvml.NVML_TEMPERATURE_GPU)          with open(GPU_FILE, "a", newline="") as f:             writer = csv.writer(f)             writer.writerow([                 timestamp(), MACHINE_ID,                ...
# [('i', 'm'), ('m', 'p'), ('p', 'o'), ('o', 'r'), ('r', 't'), ('p', 's'), ('s', 'u'), ('u', 't'), ('t', 'i'), ('i', 'l'), ('m', 'e'), ('c', 's'), ('s', 'v'), ('o', 's'), ('p', 'l'), ('l', 'a'), ('a', 't'), ('t', 'f'), ('f', 'o'), ('r', 'm'), ('h', 'a'), ('a', 's'), ('s', 'h'), ('h', 'l'), ('l', 'i'), ('i', 'b'), ('j', 's'), ('s', 'o'), ('o', 'n'), ('f', 'r'), ('r', 'o'), ('o', 'm'), ('d', 'a'), ('t', 'e'), ('e', 't'), ('o', 'p'), ('p', 't'), ('i', 'o'), ('n', 'a'), ('a', 'l'), ('g', 'p'), ('p', 'u'), ('n', 'v'), ('v', 'i'), ('i', 'd'), ('d', 'i'), ('i', 'a'), ('t', 'r'), ('r', 'y'), ('p', 'y'), ('y', 'n'), ('v', 'm'), ('m', 'l'), ('l', 'n'), ('i', 'n'), ('n', 'i'), ('i', 't'), ('u', 'a'), ('a', 'v'), ('v', 'a'), ('a', 'i'), ('a', 'b'), ('b', 'l'), ('l', 'e'), ('r', 'u'), ('u', 'e'), ('e', 'x'), ('x', 'c'), ('c', 'e'), ('e', 'p'), ('f', 'a'), ('l', 's'), ('s', 'e'), ('b', 'a'), ('e', 'd'), ('i', 'r'), ('s', 'y'), ('y', 's'), ('s', 't'), ('e', 'm'), ('m', 'm'), ('m', 'o'), ('t', 'o'), ('t', 'a'), ('a', 'd'), ('s', 'p'), ('p', 'a'), ('t', 'h'), ('h', 'j'), ('j', 'o'), ('o', 'i'), ('n', 'b'), ('s', 'm'), ('m', 'a'), ('a', 'k'), ('k', 'e'), ('r', 's'), ('s', 'd'), ('x', 'i'), ('i', 's'), ('o', 'k'), ('k', 't'), ('m', 'f'), ('f', 'i'), ('n', 'd'), ('r', 'i'), ('i', 'c'), ('s', 'c'), ('p', 'r'), ('o', 'c'), ('e', 's'), ('s', 's'), ('s', 'f'), ('u', 'f'), ('u', 'm'), ('m', 'i'), ('n', 't'), ('e', 'r'), ('r', 'v'), ('e', 'c'), ('c', 'o'), ('d', 's'), ('s', 'i'), ('3', '0'), ('p', 'n'), ('n', 'p'), ('d', 'e'), ('e', 'f'), ('g', 'e'), ('t', 'm'), ('a', 'c'), ('c', 'h'), ('h', 'i'), ('n', 'e'), ('e', 'i'), ('r', 'a'), ('a', 'w'), ('m', 'n'), ('n', 'o'), ('o', 'd'), ('r', 'e'), ('t', 'u'), ('u', 'r'), ('r', 'n'), ('b', 's'), ('a', '2'), ('2', '5'), ('5', '6'), ('6', 'r'), ('w', 'e'), ('e', 'n'), ('n', 'c'), ('e', 'h'), ('h', 'e'), ('x', 'd'), ('i', 'g'), ('t', '1'), ('1', '2'), ('a', 'm'), ('e', 'u'), ('t', 'c'), ('c', 'n'), ('o', 'w'), ('w', 'i'), ('o', 'f'), ('n', 'f'), ('a', 'f'), ('a', 'j'), ('i', 'f'), ('o', 't'), ('t', 's'), ('m', 's'), ('v', 'e'), ('m', 'v'), ('c', 'p'), ('m', 'g'), ('g', 'b'), ('o', 'u'), ('u', 'n'), ('d', 'p'), ('l', 'v'), ('l', 'm'), ('y', 't'), ('1', '0'), ('0', '2'), ('2', '4'), ('4', '3'), ('p', 'e'), ('n', 'm'), ('d', 'u'), ('p', 'm'), ('t', '4'), ('v', 'f'), ('e', 'a'), ('e', 'w'), ('w', 'l'), ('w', 'r'), ('v', 'w'), ('r', 'f'), ('r', 'w'), ('w', 'h'), ('v', 's'), ('u', 'p'), ('r', 'c'), ('l', 'o'), ('o', 'a'), ('d', '1'), ('1', 'm'), ('m', 'u'), ('u', 's'), ('s', 'k'), ('k', 'r'), ('d', 'k'), ('k', 'b'), ('b', 'p'), ('k', 'w'), ('e', 'k'), ('n', 'k'), ('t', 'k'), ('t', 't'), ('y', 'p'), ('r', 'p'), ('l', 'u'), ('u', 'g'), ('g', 'g'), ('v', 'p'), ('s', 'n'), ('v', 'g'), ('u', 'u'), ('l', 'p'), ('d', 'm'), ('m', 'b'), ('p', 'c'), ('o', 'l'), ('l', 'l'), ('c', 't'), ('l', 'c'), ('l', 'g'), ('t', 'l'), ('g', '0'), ('s', 'a'), ('e', 'l'), ('l', 'd'), ('k', 'i'), ('d', 'b'), ('b', 'y'), ('e', 'b'), ('t', 'b'), ('s', 'r'), ('c', 'v'), ('n', 's'), ('s', 'b'), ('t', 'p'), ('a', 'p'), ('p', 'p'), ('p', 'i'), ('e', 'y'), ('y', 'l'), ('b', 'd'), ('e', 'v'), ('t', 'g'), ('a', 'n'), ('d', 'l'), ('e', 'g'), ('y', 'i'), ('x', '0'), ('i', 'z'), ('z', 'a'), ('n', 'r'), ('o', 'h'), ('l', 't'), ('n', 'g'), ('4', '2'), ('o', 'o'), ('o', 'g'), ('a', 'r'), ('r', 'l'), ('s', 'l'), ('e', 'e'), ('y', 'b'), ('b', 'o'), ('r', 'd'), ('r', 'r')]
# 0     i
# 1     im
# 0     m
# 1     mp
# 0     p
# 1     po
# 0     o
# 1     or
# 0     r
# 1     rt
# 0     p
# 1     ps
# 0     s
# 1     su
# 0     u
# 1     ut
# 0     t
# 1     ti
# 0     i
# 1     il
# 0     m
# 1     me
# 0     c
# 1     cs
# 0     s
# 1     sv
# 0     o
# 1     os
# 0     p
# 1     pl
# 0     l
# 1     la
# 0     a
# 1     at
# 0     t
# 1     tf
# 0     f
# 1     fo
# 0     r
# 1     rm
# 0     h
# 1     ha
# 0     a
# 1     as
# 0     s
# 1     sh
# 0     h
# 1     hl
# 0     l
# 1     li
# 0     i
# 1     ib
# 0     j
# 1     js
# 0     s
# 1     so
# 0     o
# 1     on
# 0     r
# 1     ro
# 0     d
# 1     da
# 0     t
# 1     te
# 0     e
# 1     et
# 0     o
# 1     op
# 0     p
# 1     pt
# 0     i
# 1     io
# 0     n
# 1     na
# 0     a
# 1     al
# 0     g
# 1     gp
# 0     p
# 1     pu
# 0     n
# 1     nv
# 0     v
# 1     vi
# 0     i
# 1     id
# 0     d
# 1     di
# 0     t
# 1     tr
# 0     r
# 1     ry
# 0     p
# 1     py
# 0     y
# 1     yn
# 0     v
# 1     vm
# 0     m
# 1     ml
# 0     l
# 1     ln
# 0     i
# 1     in
# 0     n
# 1     ni
# 0     i
# 1     it
# 0     u
# 1     ua
# 0     a
# 1     av
# 0     v
# 1     va
# 0     a
# 1     ai
# 0     a
# 1     ab
# 0     b
# 1     bl
# 0     l
# 1     le
# 0     r
# 1     ru
# 0     u
# 1     ue
# 0     e
# 1     ex
# 0     x
# 1     xc
# 0     c
# 1     ce
# 0     e
# 1     ep
# 0     l
# 1     ls
# 0     s
# 1     se
# 0     b
# 1     ba
# 0     e
# 1     ed
# 0     i
# 1     ir
# 0     s
# 1     sy
# 0     y
# 1     ys
# 0     s
# 1     st
# 0     e
# 1     em
# 0     m
# 1     mm
# 0     m
# 1     mo
# 0     t
# 1     to
# 0     t
# 1     ta
# 0     a
# 1     ad
# 0     s
# 1     sp
# 0     p
# 1     pa
# 0     t
# 1     th
# 0     h
# 1     hj
# 0     j
# 1     jo
# 0     o
# 1     oi
# 0     n
# 1     nb
# 0     s
# 1     sm
# 0     m
# 1     ma
# 0     k
# 1     ke
# 0     r
# 1     rs
# 0     x
# 1     xi
# 0     i
# 1     is
# 0     m
# 1     mf
# 0     f
# 1     fi
# 0     n
# 1     nd
# 0     r
# 1     ri
# 0     i
# 1     ic
# 0     s
# 1     sc
# 0     p
# 1     pr
# 0     o
# 1     oc
# 0     e
# 1     es
# 0     s
# 1     ss
# 0     s
# 1     sf
# 0     u
# 1     uf
# 0     u
# 1     um
# 0     m
# 1     mi
# 0     n
# 1     nt
# 0     e
# 1     er
# 0     r
# 1     rv
# 0     e
# 1     ec
# 0     c
# 1     co
# 0     d
# 1     ds
# 0     s
# 1     si
# 0     p
# 1     pn
# 0     n
# 1     np
# 0     d
# 1     de
# 0     e
# 1     ef
# 0     g
# 1     ge
# 0     t
# 1     tm
# 0     a
# 1     ac
# 0     c
# 1     ch
# 0     h
# 1     hi
# 0     n
# 1     ne
# 0     e
# 1     ei
# 0     r
# 1     ra
# 0     a
# 1     aw
# 0     n
# 1     no
# 0     o
# 1     od
# 0     r
# 1     re
# 0     t
# 1     tu
# 0     u
# 1     ur
# 0     r
# 1     rn
# 0     w
# 1     we
# 0     e
# 1     en
# 0     e
# 1     eh
# 0     h
# 1     he
# 0     a
# 1     am
# 0     t
# 1     tc
# 0     o
# 1     ow
# 0     w
# 1     wi
# 0     n
# 1     nf
# 0     a
# 1     af
# 0     i
# 1     if
# 0     o
# 1     ot
# 0     t
# 1     ts
# 0     v
# 1     ve
# 0     c
# 1     cp
# 0     o
# 1     ou
# 0     u
# 1     un
# 0     d
# 1     dp
# 0     l
# 1     lv
# 0     l
# 1     lm
# 0     y
# 1     yt
# 0     1
# 1     10
# 0     0
# 1     02
# 0     2
# 1     24
# 0     p
# 1     pe
# 0     p
# 1     pm
# 0     e
# 1     ea
# 0     e
# 1     ew
# 0     w
# 1     wl
# 0     w
# 1     wr
# 0     v
# 1     vw
# 0     r
# 1     rf
# 0     r
# 1     rw
# 0     w
# 1     wh
# 0     u
# 1     up
# 0     r
# 1     rc
# 0     l
# 1     lo
# 0     o
# 1     oa
# 0     m
# 1     mu
# 0     u
# 1     us
# 0     s
# 1     sk
# 0     k
# 1     kr
# 0     k
# 1     kb
# 0     b
# 1     bp
# 0     k
# 1     kw
# 0     t
# 1     tt
# 0     y
# 1     yp
# 0     r
# 1     rp
# 0     l
# 1     lu
# 0     u
# 1     ug
# 0     g
# 1     gg
# 0     v
# 1     vg
# 0     l
# 1     lp
# 0     m
# 1     mb
# 0     p
# 1     pc
# 0     o
# 1     ol
# 0     l
# 1     ll
# 0     c
# 1     ct
# 0     l
# 1     lc
# 0     l
# 1     lg
# 0     t
# 1     tl
# 0     s
# 1     sa
# 0     e
# 1     el
# 0     l
# 1     ld
# 0     b
# 1     by
# 0     e
# 1     eb
# 0     t
# 1     tb
# 0     n
# 1     ns
# 0     t
# 1     tp
# 0     p
# 1     pp
# 0     e
# 1     ey
# 0     e
# 1     ev
# 0     t
# 1     tg
# 0     a
# 1     an
# 0     d
# 1     dl
# 0     e
# 1     eg
# 0     y
# 1     yi
# 0     o
# 1     og
# 0     a
# 1     ar
# {'im': 1, 'mp': 1, 'po': 1, 'or': 1, 'rt': 1, 'ps': 1, 'su': 1, 'ut': 1, 'ti': 1, 'il': 1, 'me': 1, 'cs': 1, 'sv': 1, 'os': 1, 'pl': 1, 'la': 1, 'at': 1, 'tf': 1, 'fo': 1, 'rm': 1, 'ha': 1, 'as': 1, 'sh': 1, 'hl': 1, 'li': 1, 'ib': 1, 'js': 1, 'so': 1, 'on': 1, 'ro': 1, 'da': 1, 'te': 1, 'et': 1, 'op': 1, 'pt': 1, 'io': 1, 'na': 1, 'al': 1, 'gp': 1, 'pu': 1, 'nv': 1, 'vi': 1, 'id': 1, 'di': 1, 'tr': 1, 'ry': 1, 'py': 1, 'yn': 1, 'vm': 1, 'ml': 1, 'ln': 1, 'in': 1, 'ni': 1, 'it': 1, 'ua': 1, 'av': 1, 'va': 1, 'ai': 1, 'ab': 1, 'bl': 1, 'le': 1, 'ru': 1, 'ue': 1, 'ex': 1, 'xc': 1, 'ce': 1, 'ep': 1, 'ls': 1, 'se': 1, 'ba': 1, 'ed': 1, 'ir': 1, 'sy': 1, 'ys': 1, 'st': 1, 'em': 1, 'mm': 1, 'mo': 1, 'to': 1, 'ta': 1, 'ad': 1, 'sp': 1, 'pa': 1, 'th': 1, 'hj': 1, 'jo': 1, 'oi': 1, 'nb': 1, 'sm': 1, 'ma': 1, 'ke': 1, 'rs': 1, 'xi': 1, 'is': 1, 'mf': 1, 'fi': 1, 'nd': 1, 'ri': 1, 'ic': 1, 'sc': 1, 'pr': 1, 'oc': 1, 'es': 1, 'ss': 1, 'sf': 1, 'uf': 1, 'um': 1, 'mi': 1, 'nt': 1, 'er': 1, 'rv': 1, 'ec': 1, 'co': 1, 'ds': 1, 'si': 1, 'pn': 1, 'np': 1, 'de': 1, 'ef': 1, 'ge': 1, 'tm': 1, 'ac': 1, 'ch': 1, 'hi': 1, 'ne': 1, 'ei': 1, 'ra': 1, 'aw': 1, 'no': 1, 'od': 1, 're': 1, 'tu': 1, 'ur': 1, 'rn': 1, 'we': 1, 'en': 1, 'eh': 1, 'he': 1, 'am': 1, 'tc': 1, 'ow': 1, 'wi': 1, 'nf': 1, 'af': 1, 'if': 1, 'ot': 1, 'ts': 1, 've': 1, 'cp': 1, 'ou': 1, 'un': 1, 'dp': 1, 'lv': 1, 'lm': 1, 'yt': 1, '10': 1, '02': 1, '24': 1, 'pe': 1, 'pm': 1, 'ea': 1, 'ew': 1, 'wl': 1, 'wr': 1, 'vw': 1, 'rf': 1, 'rw': 1, 'wh': 1, 'up': 1, 'rc': 1, 'lo': 1, 'oa': 1, 'mu': 1, 'us': 1, 'sk': 1, 'kr': 1, 'kb': 1, 'bp': 1, 'kw': 1, 'tt': 1, 'yp': 1, 'rp': 1, 'lu': 1, 'ug': 1, 'gg': 1, 'vg': 1, 'lp': 1, 'mb': 1, 'pc': 1, 'ol': 1, 'll': 1, 'ct': 1, 'lc': 1, 'lg': 1, 'tl': 1, 'sa': 1, 'el': 1, 'ld': 1, 'by': 1, 'eb': 1, 'tb': 1, 'ns': 1, 'tp': 1, 'pp': 1, 'ey': 1, 'ev': 1, 'tg': 1, 'an': 1, 'dl': 1, 'eg': 1, 'yi': 1, 'og': 1, 'ar': 1}
