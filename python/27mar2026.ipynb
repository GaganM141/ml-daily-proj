# %% [markdown]
# # 1. l=['hello',745,79.5,65]
# # out=['hello',547,79.5,56]

# %%
l=['hello',745,79.5,63,52552,14.5,'bye']
out =[]
for i in l:
    if type(i)==int:
        rev=0
        while i!=0:
            d=i%10
            rev=(rev*10)+d
            i=i//10
        out.append(rev)
    else:
        out.append(i)
print(out)
# Out:
# ['hello', 547, 79.5, 36, 25525, 14.5, 'bye']

# %% [markdown]
# # Patterns

# %%
l=3
for i in range(l):
    for j in range(l):
        print('*', end=' ')
    print(end='\n')
# Out:
# * * *
# * * *
# * * *

# %%
r=int(input('enter a row number'))
c=int(input('enter a col number'))
for i in range(r):
    for j in range(c):
        print('*', end=' ')
    print(end='\n')
# Out:
# enter a row number23
# enter a col number23
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *

# %%
r=3
c=4
for i in range(r):
    print('*'*c)
# Out:
# ****
# ****
# ****

# %%
for i in range(1,4):
    for j in range(1,4):
        print(i*j,end=' ')
    print()
# Out:
# 1 2 3
# 2 4 6
# 3 6 9

# %%
for i in range(1,4):
    for j in range(1,4):
        print(j,end=' ')
    print()
# Out:
# 1 2 3
# 1 2 3
# 1 2 3

# %%
for i in range(1,4):
    for j in range(1,4):
        print(i,end='')
    print()
# Out:
# 111
# 222
# 333

# %%
n=5
for i in range(1,n+1):
    print(str(i)*n)
# Out:
# 11111
# 22222
# 33333
# 44444
# 55555

# %%
for i in range(1,4):
    for j in range(1,4):
        if i!=j:
            print(' ',end=' ')
        else:
            print(i*j,end='')
    print()
# Out:
# 1
#   4
#     9

# %%
for i in range(1,4):
    for j in range(1,4):
        if i!=j:
            print(' ',end=' ')
        else:
            print(j,end='')
    print()
# Out:
# 1
#   2
#     3

# %%
n=5
for i in range(1,n):
    for j in range(1,n):
        if i!=n-j:
            print(' ',end=' ')
        else:
            print(j,end='')
    print()
# Out:
#       4
#     3
#   2
# 1

# %%
for i in range(1,5):
    print('*'*i)
# Out:
# *
# **
# ***
# ****

# %%
name='gagan'
for i in range(len(name)):
    for j in range(len(name)):
        if i!=j:
            print(' ', end=' ')
        else:
            print(name[i],end=' ')
    print()
# Out:
# g
#   a
#     g
#       a
#         n

# %%
name='bharath'
for i  in range(len(name)):
    for j in range(len(name)+1):
        if i!=len(name)-j:
            print(' ',end=' ')
        else:
            print(name[i],end=' ')
    print()
# Out:
#               b
#             h
#           a
#         r
#       a
#     t
#   h

# %%
n=7
for i in range(1,n+1):
    print(' '*(i)+'*'*(n-i))
# Out:
#  ******
#   *****
#    ****
#     ***
#      **
#       *

# %%
for i in range(1,n+1):
    print(' '*(n-i)+'*'*(i*2-1))
# Out:
#       *
#      ***
#     *****
#    *******
#   *********
#  ***********
# *************

# %%
name='gagan'
for i in range(0,len(name),2):
    for j in range(len(name)):
        if i!=j:
            print('', end=' ')
        else:
            print(name[i],end=' ')
    print()
# Out:
# g
#   g
#     n

# %%
name='gagan'
for i in range(0,len(name)):
    for j in range(len(name)):
        if i!=j:
            print(' ', end=' ')
        elif i%2!=0:
            print(' ',end=' ')
        else:
            print(name[i],end=' ')
    print()
# Out:
# g
#
#     g
#
#         n

# %%
n=5
for i in range(n):
    for j in range(n):
        if i==j:
            print('*',end='')
        elif j==n-i-1:
            print('*',end='')
        else:
            print(' ',end='')
    print()
# Out:
# *   *
#  * *
#   *
#  * *
# *   *

# %%
n=9
for i in range(n):
    for j in range(n):
        if i==j or j==n-i-1 or i==n//2:
            print('*',end=' ')
        else:
            print(' ',end=' ')
    print()
# Out:
# *               *
#   *           *
#     *       *
#       *   *
# * * * * * * * * *
#       *   *
#     *       *
#   *           *
# *               *

# %%
n=27
for i in range(n):
    for j in range(n):
        if i==j or j==n-i-1 or i==n//2 or j==n//2:
            print('*',end=' ')
        else:
            print(' ',end=' ')
    print()
# Out:
# *                         *                         *
#   *                       *                       *
#     *                     *                     *
#       *                   *                   *
#         *                 *                 *
#           *               *               *
#             *             *             *
#               *           *           *
#                 *         *         *
#                   *       *       *
#                     *     *     *
#                       *   *   *
#                         * * *
# * * * * * * * * * * * * * * * * * * * * * * * * * * *
#                         * * *
#                       *   *   *
#                     *     *     *
#                   *       *       *
#                 *         *         *
#               *           *           *
#             *             *             *
#           *               *               *
#         *                 *                 *
#       *                   *                   *
#     *                     *                     *
#   *                       *                       *
# *                         *                         *

# %%
n=8
for i in range(n):
    for j in range(n):
        if i==j:
            print('#',end='')
        elif i<j:
            print('@',end='')
        else:
            print('*',end='')
    print()
# Out:
# #@@@@@@@
# *#@@@@@@
# **#@@@@@
# ***#@@@@
# ****#@@@
# *****#@@
# ******#@
# *******#

# %%
for i in range(1,n+1):
    for j in range(1,n+1):
        if i%2==0:
            print(i**2, end='\t ')
        else:
            print(i,end=' \t')
    print()
# Out:
# 1 	1 	1 	1 	1 	1 	1 	1
# 4	 4	 4	 4	 4	 4	 4	 4
# 3 	3 	3 	3 	3 	3 	3 	3
# 16	 16	 16	 16	 16	 16	 16	 16
# 5 	5 	5 	5 	5 	5 	5 	5
# 36	 36	 36	 36	 36	 36	 36	 36
# 7 	7 	7 	7 	7 	7 	7 	7
# 64	 64	 64	 64	 64	 64	 64	 64
