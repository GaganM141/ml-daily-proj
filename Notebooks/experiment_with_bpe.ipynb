# %%
def clean(text):
    texts=''
    for ch in text:
        if ch.isalnum() or ch==' ':
            texts+=ch.lower()
    return texts

# %%
def ch_token(text):
    clean_text=clean(text)
    ch_text=[]
    for ch in clean_text:
        if ch!=' ':
            ch_text.append(ch)
        else:
            ch_text.append('</w>')
    #print('ch_text:',ch_text,sep='\n',end='\n\n\n')
    return ch_text

# %%
def count_pair(text):
    ch_tokens=text
    Dcount_pair={}
    for i in range(0,len(ch_tokens)-1):
        if ch_tokens[i]=='</w>':
            continue
        pair=(ch_tokens[i],ch_tokens[i+1])
        if '</w>' not in pair:
            if pair not in Dcount_pair:
                Dcount_pair[pair]=1
            else:
                Dcount_pair[pair]+=1
    #print("dcount_pair",Dcount_pair,sep='\n')
    return Dcount_pair

# %%
'''def merge_frequent_pair(text):
    count_pairs=count_pair(text)
    pairs=list(count_pairs.keys())
    print(pairs)
    merge_ch={}
    for i in count_pairs:
        if count_pairs[i]!=1:
            #print(i,"    ",count_pairs[i])
            merge=''
            #print(pairs[i])
            for j in range(0,len(pairs[i])):
                merge+=pairs[i][j]
                print(j,"   ",merge)
            merge_ch[merge]=1
        else:
            continue
    return merge_ch
       '''
# Out:
# 'def merge_frequent_pair(text):\n    count_pairs=count_pair(text)\n    pairs=list(count_pairs.keys())\n    print(pairs)\n    merge_ch={}\n    for i in count_pairs:\n        if count_pairs[i]!=1:\n            #print(i,"    ",count_pairs[i])\n            merge=\'\'\n            #print(pairs[i])\n            for j in range(0,len(pairs[i])):\n                merge+=pairs[i][j]\n                print(j,"   ",merge)\n            merge_ch[merge]=1\n        else:\n            continue\n    return merge_ch\n       '

# %%
'''def merge_frequent_pair(text):
    count_pairs=count_pair(text)
    pairs=list(count_pairs.keys())
    print(pairs)
    merge_ch={}
    for i in count_pairs:
        if count_pairs[i]!=1:
            #print(i,"    ",count_pairs[i])
            merge=''
            #print(pairs[i])
            for j in range(len(i)):
                merge+=i[j]
                print(j,"   ",merge)
            merge_ch[merge]=1
        else:
            continue
    return merge_ch
    '''
# this code updates all pair which effects the merging process
# Out:
# 'def merge_frequent_pair(text):\n    count_pairs=count_pair(text)\n    pairs=list(count_pairs.keys())\n    print(pairs)\n    merge_ch={}\n    for i in count_pairs:\n        if count_pairs[i]!=1:\n            #print(i,"    ",count_pairs[i])\n            merge=\'\'\n            #print(pairs[i])\n            for j in range(len(i)):\n                merge+=i[j]\n                print(j,"   ",merge)\n            merge_ch[merge]=1\n        else:\n            continue\n    return merge_ch\n    '

# %%
def best_pair(text):
    pair_count=text
    max_count=0
    best=None
    for pair in pair_count:
        print('pair',pair,'   pair_value',pair_count[pair],sep='     ',end='\n')
        if pair_count[pair]>max_count:
            max_count=pair_count[pair]
            print('max count    ',max_count)
            best=pair
    #print('best',best)
    return best

# %%
def merge_best_pair(tokens,pair):
    new_tokens=[]
    i=0
    while i<len(tokens):
        if i<len(tokens)-1 and tokens[i]==pair[0] and tokens[i+1]==pair[1]:
            merged=tokens[i]+tokens[i+1]
            new_tokens.append(merged)
            i+=2
        else:
            new_tokens.append(tokens[i])
            i+=1
    return new_tokens

# %%
def train_bpe(text,iterations):
    tokens=ch_token(text)
    for i in range(iterations):
        pair_counts=count_pair(tokens)
        pair=best_pair(pair_counts)
        if pair_counts[pair]==1 :
            break
        print('merge pair:',pair)
        tokens=merge_best_pair(tokens,pair)
        print('updated tokens:',tokens)
    return tokens

# %%
text_in=input('enter')
bpe=train_bpe(text_in,1000)
print('bpe of given text is :',bpe, sep='\n')
# Out:
# enterimport psutil import time import csv import os import platform import hashlib import json from datetime import datetime  # Optional GPU (NVIDIA) try:     import pynvml     pynvml.nvmlInit()     GPU_AVAILABLE = True except:     GPU_AVAILABLE = False  BASE_DIR = "system_monitor" DATA_DIR = os.path.join(BASE_DIR, "data") os.makedirs(DATA_DIR, exist_ok=True)  SYSTEM_FILE = os.path.join(DATA_DIR, "system_metrics.csv") PROCESS_FILE = os.path.join(DATA_DIR, "process_metrics.csv") GPU_FILE = os.path.join(DATA_DIR, "gpu_metrics.csv")  SYSTEM_INTERVAL = 5      # seconds PROCESS_INTERVAL = 30    # seconds TOP_N_PROCESSES = 5  # ------------------ UTILS ------------------  def get_machine_id():     raw = platform.node() + platform.processor()     return hashlib.sha256(raw.encode()).hexdigest()[:12]  MACHINE_ID = get_machine_id()  def timestamp():     return datetime.utcnow().isoformat()  # ------------------ META INFO ------------------  META_FILE = os.path.join(BASE_DIR, "machine_meta.json") if not os.path.exists(META_FILE):     meta = {         "machine_id": MACHINE_ID,         "os": platform.system(),         "os_version": platform.version(),         "cpu": platform.processor(),         "ram_gb": round(psutil.virtual_memory().total / (1024**3), 2)     }     with open(META_FILE, "w") as f:         json.dump(meta, f, indent=4)  # ------------------ CSV INIT ------------------  def init_csv(file, header):     if not os.path.exists(file):         with open(file, "w", newline="") as f:             writer = csv.writer(f)             writer.writerow(header)  init_csv(SYSTEM_FILE, [     "timestamp", "machine_id",     "cpu_percent", "load_1m",     "mem_used_percent",     "disk_read_kbps", "disk_write_kbps",     "net_in_kbps", "net_out_kbps",     "battery_percent", "power_plugged" ])  init_csv(PROCESS_FILE, [     "timestamp", "machine_id",     "process_name", "cpu_percent", "mem_percent" ])  init_csv(GPU_FILE, [     "timestamp", "machine_id",     "gpu_util_percent", "gpu_mem_used_mb", "gpu_temp_c" ])  # ------------------ METRIC COLLECTION ------------------  def collect_system_metrics():     cpu = psutil.cpu_percent()     load = psutil.getloadavg()[0] if hasattr(psutil, "getloadavg") else 0     mem = psutil.virtual_memory().percent      disk = psutil.disk_io_counters()     disk_read = disk.read_bytes / 1024     disk_write = disk.write_bytes / 1024      net = psutil.net_io_counters()     net_in = net.bytes_recv / 1024     net_out = net.bytes_sent / 1024      battery = psutil.sensors_battery()     battery_percent = battery.percent if battery else None     plugged = battery.power_plugged if battery else None      with open(SYSTEM_FILE, "a", newline="") as f:         writer = csv.writer(f)         writer.writerow([             timestamp(), MACHINE_ID,             cpu, load, mem,             disk_read, disk_write,             net_in, net_out,             battery_percent, plugged         ])  def collect_process_metrics():     processes = []     for p in psutil.process_iter(['name', 'cpu_percent', 'memory_percent']):         try:             processes.append(p.info)         except:             pass      top = sorted(processes, key=lambda x: x['cpu_percent'], reverse=True)[:TOP_N_PROCESSES]      with open(PROCESS_FILE, "a", newline="") as f:         writer = csv.writer(f)         for p in top:             writer.writerow([                 timestamp(), MACHINE_ID,                 p['name'], p['cpu_percent'], p['memory_percent']             ])  def collect_gpu_metrics():     if not GPU_AVAILABLE:         return      try:         handle = pynvml.nvmlDeviceGetHandleByIndex(0)         util = pynvml.nvmlDeviceGetUtilizationRates(handle)         mem = pynvml.nvmlDeviceGetMemoryInfo(handle)         temp = pynvml.nvmlDeviceGetTemperature(handle, pynvml.NVML_TEMPERATURE_GPU)          with open(GPU_FILE, "a", newline="") as f:             writer = csv.writer(f)             writer.writerow([                 timestamp(), MACHINE_ID,                 util.gpu, m ...
# dcount_pair
# {('i', 'm'): 26, ('m', 'p'): 25, ('p', 'o'): 11, ('o', 'r'): 28, ('r', 't'): 13, ('p', 's'): 15, ('s', 'u'): 10, ('u', 't'): 20, ('t', 'i'): 39, ('i', 'l'): 34, ('m', 'e'): 49, ('c', 's'): 22, ('s', 'v'): 14, ('o', 's'): 11, ('p', 'l'): 10, ('l', 'a'): 13, ('a', 't'): 37, ('t', 'f'): 6, ('f', 'o'): 12, ('r', 'm'): 7, ('h', 'a'): 9, ('a', 's'): 16, ('s', 'h'): 4, ('h', 'l'): 2, ('l', 'i'): 8, ('i', 'b'): 2, ('j', 's'): 3, ('s', 'o'): 8, ('o', 'n'): 13, ('f', 'r'): 1, ('r', 'o'): 26, ('o', 'm'): 1, ('d', 'a'): 12, ('t', 'e'): 63, ('e', 't'): 44, ('o', 'p'): 13, ('p', 't'): 6, ('i', 'o'): 7, ('n', 'a'): 4, ('a', 'l'): 9, ('g', 'p'): 15, ('p', 'u'): 24, ('n', 'v'): 14, ('v', 'i'): 7, ('i', 'd'): 12, ('d', 'i'): 22, ('i', 'a'): 1, ('t', 'r'): 20, ('r', 'y'): 18, ('p', 'y'): 7, ('y', 'n'): 7, ('v', 'm'): 13, ('m', 'l'): 13, ('l', 'n'): 7, ('i', 'n'): 45, ('n', 'i'): 7, ('i', 't'): 33, ('u', 'a'): 5, ('a', 'v'): 5, ('v', 'a'): 7, ('a', 'i'): 4, ('a', 'b'): 3, ('b', 'l'): 3, ('l', 'e'): 32, ('r', 'u'): 5, ('u', 'e'): 4, ('e', 'x'): 9, ('x', 'c'): 5, ('c', 'e'): 44, ('e', 'p'): 5, ('f', 'a'): 1, ('l', 's'): 6, ('s', 'e'): 20, ('b', 'a'): 12, ('e', 'd'): 14, ('i', 'r'): 11, ('s', 'y'): 11, ('y', 's'): 11, ('s', 't'): 31, ('e', 'm'): 29, ('m', 'm'): 4, ('m', 'o'): 6, ('t', 'o'): 13, ('t', 'a'): 22, ('a', 'd'): 16, ('s', 'p'): 7, ('p', 'a'): 9, ('t', 'h'): 13, ('h', 'j'): 5, ('j', 'o'
, ('t', 't'): 11, ('y', 'p'): 8, ('r', 'p'): 3, ('l', 'u'): 4, ('u', 'g'): 4, ('g', 'g'): 6, ('v', 'p'): 1, ('s', 'n'): 1, ('v', 'g'): 3, ('u', 'u'): 1, ('l', 'p'): 2, ('d', 'm'): 1, ('m', 'b'): 2, ('p', 'c'): 2, ('o', 'l'): 7, ('l', 'l'): 7, ('c', 't'): 8, ('l', 'c'): 2, ('l', 'g'): 2, ('t', 'l'): 3, ('g', '0'): 1, ('s', 'a'): 2, ('e', 'l'): 3, ('l', 'd'): 5, ('k', 'i'): 1, ('d', 'b'): 1, ('b', 'y'): 5, ('e', 'b'): 2, ('t', 'b'): 2, ('s', 'r'): 1, ('c', 'v'): 1, ('n', 's'): 2, ('s', 'b'): 1, ('t', 'p'): 5, ('a', 'p'): 1, ('p', 'p'): 2, ('p', 'i'): 1, ('e', 'y'): 2, ('y', 'l'): 1, ('b', 'd'): 1, ('e', 'v'): 5, ('t', 'g'): 2, ('a ...
# pair     ('i', 'm')        pair_value     26
# max count     26
# pair     ('m', 'p')        pair_value     25
# pair     ('p', 'o')        pair_value     11
# pair     ('o', 'r')        pair_value     28
# max count     28
# pair     ('r', 't')        pair_value     13
# pair     ('p', 's')        pair_value     15
# pair     ('s', 'u')        pair_value     10
# pair     ('u', 't')        pair_value     20
# pair     ('t', 'i')        pair_value     39
# max count     39
# pair     ('i', 'l')        pair_value     34
# pair     ('m', 'e')        pair_value     49
# max count     49
# pair     ('c', 's')        pair_value     22
# pair     ('s', 'v')        pair_value     14
# pair     ('o', 's')        pair_value     11
# pair     ('p', 'l')        pair_value     10
# pair     ('l', 'a')        pair_value     13
# pair     ('a', 't')        pair_value     37
# pair     ('t', 'f')        pair_value     6
# pair     ('f', 'o')        pair_value     12
# pair     ('r', 'm')        pair_value     7
# pair     ('h', 'a')        pair_value     9
# pair     ('a', 's')        pair_value     16
# pair     ('s', 'h')        pair_value     4
# pair     ('h', 'l')        pair_value     2
# pair     ('l', 'i')        pair_value     8
# pair     ('i', 'b')        pair_value     2
# pair     ('j', 's')        pair_value     3
# pair     ('s', 'o')        pair_value     8
# pair     ('o', 'n')        pair_value     13
# pair     ('f', 'r')        pair_value     1
# pair     ('r', 'o')        pair_value     26
# pair     ('o', 'm')        pair_value     1
# pair     ('d', 'a')        pair_value     12
# pair     ('t', 'e')        pair_value     63
# max count     63
# pair     ('e', 't')        pair_value     44
# pair     ('o', 'p')        pair_value     13
# pair     ('p', 't')        pair_value     6
# pair     ('i', 'o')        pair_value     7
# pair     ('n', 'a')        pair_value     4
# pair     ('a', 'l')        pair_value     9
# pair     ('g', 'p')        pair_value     15
# pair     ('p', 'u')        pair_value     24
# pair     ('n', 'v')        pair_value     14
# pair     ('v', 'i')        pair_value     7
# pair     ('i', 'd')        pair_value     12
# pair     ('d', 'i')        pair_value     22
# pair     ('i', 'a')        pair_value     1
# pair     ('t', 'r')        pair_value     20
# pair     ('r', 'y')        pair_value     18
# pair     ('p', 'y')        pair_value     7
# pair     ('y', 'n')        pair_value     7
# pair     ('v', 'm')        pair_value     13
# pair     ('m', 'l')        pair_value     13
# pair     ('l', 'n')        pair_value     7
# pair     ('i', 'n')        pair_value     45
# pair     ('n', 'i')        pair_value     7
# pair     ('i', 't')        pair_value     33
# pair     ('u', 'a')        pair_value     5
# pair     ('a', 'v')        pair_value     5
# pair     ('v', 'a')        pair_value     7
# pair     ('a', 'i')        pair_value     4
# pair     ('a', 'b')        pair_value     3
# pair     ('b', 'l')        pair_value     3
# pair     ('l', 'e')        pair_value     32
# pair     ('r', 'u')        pair_value     5
# pair     ('u', 'e')        pair_value     4
# pair     ('e', 'x')        pair_value     9
# pair     ('x', 'c')        pair_value     5
# pair     ('c', 'e')        pair_value     44
# pair     ('e', 'p')        pair_value     5
# pair     ('f', 'a')        pair_value     1
# pair     ('l', 's')        pair_value     6
# pair     ('s', 'e')        pair_value     20
# pair     ('b', 'a')        pair_value     12
# pair     ('e', 'd')        pair_value     14
# pair     ('i', 'r')        pair_value     11
# pair     ('s', 'y')        pair_value     11
# pair     ('y', 's')        pair_value     11
# pair     ('s', 't')        pair_value     31
# pair     ('e', 'm')        pair_value     29
# pair     ('m', 'm')        pair_value     4
# pair     ('m', 'o')        pair_value     6
# pair     ('t', 'o')        pair_value     13
# pair     ('t', 'a')        pair_value     22
# pair     ('a', 'd')        pair_value     16
# pair     ('s', 'p')        pair_value     7
# pair     ('p', 'a')        pair_value     9
# pair     ('t', 'h')        pair_value     13
# pair     ('h', 'j')        pair_value     5
# pair     ('j', 'o')        pair_value     5
# pair     ('o', 'i')        pair_value     5
# pair     ('n', 'b')        pair_value     2
# pair     ('s', 'm')        pair_value     5
# pair     ('m', 'a')        pair_value     15
# pair     ('a', 'k')        pair_value     1
# pair     ('k', 'e')        pair_value     3
# pair     ('r', 's')        pair_value     7
# pair     ('s', 'd')        pair_value     1
# pair     ('x', 'i')        pair_value     3
# pair     ('i', 's')        pair_value     14
# pair     ('o', 'k')        pair_value     1
# pair     ('k', 't')        pair_value     1
# pair     ('m', 'f')        pair_value     3
# pair     ('f', 'i')        pair_value     15
# pair     ('n', 'd')        pair_value     15
# pair     ('r', 'i')        pair_value     32
# pair     ('i', 'c')        pair_value     14
# pair     ('s', 'c')        pair_value     3
# pair     ('p', 'r')        pair_value     23
# pair     ('o', 'c')        pair_value     22
# pair     ('e', 's')        pair_value     40
# pair     ('s', 's')        pair_value     24
# pair     ('s', 'f')        pair_value     4
# pair     ('u', 'f')        pair_value     3
# pair     ('u', 'm')        pair_value     5
# pair     ('m', 'i')        pair_value     2
# pair     ('n', 't')        pair_value     27
# pair     ('e', 'r')        pair_value     60
# pair     ('r', 'v')        pair_value     4
# pair     ('e', 'c')        pair_value     10
# pair     ('c', 'o')        pair_value     12
# pair     ('d', 's')        pair_value     2
# pair     ('s', 'i')        pair_value     5
# pair     ('3', '0')        pair_value     1
# pair     ('p', 'n')        pair_value     3
# pair     ('n', 'p')        pair_value     3
# pair     ('d', 'e')        pair_value     16
# pair     ('e', 'f')        pair_value     6
# pair     ('g', 'e')        pair_value     15
# pair     ('t', 'm')        pair_value     3
# pair     ('a', 'c')        pair_value     12
# pair     ('c', 'h')        pair_value     12
# pair     ('h', 'i')        pair_value     13
# pair     ('n', 'e')        pair_value     32
# pair     ('e', 'i')        pair_value     11
# pair     ('r', 'a')        pair_value     6
# pair     ('a', 'w')        pair_value     2
# pair     ('m', 'n')        pair_value     1
# pair     ('n', 'o')        pair_value     10
# pair     ('o', 'd')        pair_value     2
# pair     ('r', 'e')        pair_value     12
# pair     ('t', 'u')        pair_value     8
# pair     ('u', 'r')        pair_value     5
# pair     ('r', 'n')        pair_value     4
# pair     ('b', 's')        pair_value     1
# pair     ('a', '2')        pair_value     1
# pair     ('2', '5')        pair_value     1
# pair     ('5', '6')        pair_value     1
# pair     ('6', 'r')        pair_value     1
# pair     ('w', 'e')        pair_value     3
# pair     ('e', 'n')        pair_value     26
# pair     ('n', 'c')        pair_value     1
# pair     ('e', 'h')        pair_value     2
# pair     ('h', 'e')        pair_value     5
# pair     ('x', 'd')        pair_value     1
# pair     ('i', 'g')        pair_value     1
# pair     ('t', '1')        pair_value     1
# pair     ('1', '2')        pair_value     1
# pair     ('a', 'm')        pair_value     12
# pair     ('e', 'u')        pair_value     1
# pair     ('t', 'c')        pair_value     5
# pair     ('c', 'n')        pair_value     1
# pair     ('o', 'w')        pair_value     10
# pair     ('w', 'i')        pair_value     6
# pair     ('o', 'f')        pair_value     1
# pair     ('n', 'f')        pair_value     4
# pair     ('a', 'f')        pair_value     3
# pair     ('a', 'j')        pair_value     1
# pair     ('i', 'f')        pair_value     7
# pair     ('o', 't')        pair_value     4
# pair     ('t', 's')        pair_value     5
# pair     ('m', 's')        pair_value     1
# pair     ('v', 'e')        pair_value     3
# pair     ('m', 'v')        pair_value     1
# pair     ('c', 'p')        pair_value     9
# pair     ('m', 'g')        pair_value     1
# pair     ('g', 'b')        pair_value     1
# pair     ('o', 'u')        pair_value     6
# pair     ('u', 'n')        pair_value     3
# pair     ('d', 'p')        pair_value     4
# pair     ('l', 'v')        pair_value     2
# pair     ('l', 'm')        pair_value     2
# pair     ('y', 't')        pair_value     5
# pair     ('1', '0')        pair_value     6
# pair     ('0', '2')        pair_value     6
# pair     ('2', '4')        pair_value     6
# pair     ('4', '3')        pair_value     1
# pair     ('p', 'e')        pair_value     25
# pair     ('n', 'm')        pair_value     1
# pair     ('d', 'u')        pair_value     1
# pair     ('p', 'm')        pair_value     2
# pair     ('t', '4')        pair_value     1
# pair     ('v', 'f')        pair_value     1
# pair     ('e', 'a')        pair_value     6
# pair     ('e', 'w')        pair_value     4
# pair     ('w', 'l')        pair_value     4
# pair     ('w', 'r')        pair_value     20
# pair     ('v', 'w')        pair_value     4
# pair     ('r', 'f')        pair_value     4
# pair     ('r', 'w')        pair_value     4
# pair     ('w', 'h')        pair_value     2
# pair     ('v', 's')        pair_value     1
# pair     ('u', 'p')        pair_value     7
# pair     ('r', 'c')        pair_value     16
# pair     ('l', 'o')        pair_value     8
# pair     ('o', 'a')        pair_value     6
# pair     ('d', '1')        pair_value     1
# pair     ('1', 'm')        pair_value     1
# pair     ('m', 'u')        pair_value     3
# pair     ('u', 's')        pair_value     3
# pair     ('s', 'k')        pair_value     10
# pair     ('k', 'r')        pair_value     4
# pair     ('d', 'k')        pair_value     1
# pair     ('k', 'b')        pair_value     4
# pair     ('b', 'p')        pair_value     4
# pair     ('k', 'w')        pair_value     4
# pair     ('e', 'k')        pair_value     1
# pair     ('n', 'k')        pair_value     1
# pair     ('t', 'k')        pair_value     1
# pair     ('t', 't')        pair_value     11
# pair     ('y', 'p')        pair_value     8
# pair     ('r', 'p')        pair_value     3
# pair     ('l', 'u')        pair_value     4
# pair     ('u', 'g')        pair_value     4
# pair     ('g', 'g')        pair_value     6
# pair     ('v', 'p')        pair_value     1
# pair     ('s', 'n')        pair_value     1
# pair     ('v', 'g')        pair_value     3
# pair     ('u', 'u')        pair_value     1
# pair     ('l', 'p')        pair_value     2
# pair     ('d', 'm')        pair_value     1
# pair     ('m', 'b')        pair_value     2
# pair     ('p', 'c')        pair_value     2
# pair     ('o', 'l')        pair_value     7
# pair     ('l', 'l')        pair_value     7
# pair     ('c', 't')        pair_value     8
# pair     ('l', 'c')        pair_value     2
# pair     ('l', 'g')        pair_value     2
# pair     ('t', 'l')        pair_value     3
# pair     ('g', '0')        pair_value     1
# pair     ('s', 'a')        pair_value     2
# pair     ('e', 'l')        pair_value     3
# pair     ('l', 'd')        pair_value     5
# pair     ('k', 'i')        pair_value     1
# pair     ('d', 'b')        pair_value     1
# pair     ('b', 'y')        pair_value     5
# pair     ('e', 'b')        pair_value     2
# pair     ('t', 'b')        pair_value     2
# pair     ('s', 'r')        pair_value     1
# pair     ('c', 'v')        pair_value     1
# pair     ('n', 's')        pair_value     2
# pair     ('s', 'b')        pair_value     1
# pair     ('t', 'p')        pair_value     5
# pair     ('a', 'p')        pair_value     1
# pair     ('p', 'p')        pair_value     2
# pair     ('p', 'i')        pair_value     1
# pair     ('e', 'y')        pair_value     2
# pair     ('y', 'l')        pair_value     1
# pair     ('b', 'd')        pair_value     1
# pair     ('e', 'v')        pair_value     5
# pair     ('t', 'g')        pair_value     2
# pair     ('a', 'n')        pair_value     5
# pair     ('d', 'l')        pair_value     5
# pair     ('e', 'g')        pair_value     5
# pair     ('y', 'i')        pair_value     2
# pair     ('x', '0')        pair_value     1
# pair     ('i', 'z')        pair_value     1
# pair     ('z', 'a')        pair_value     1
# pair     ('n', 'r')        pair_value     1
# pair     ('o', 'h')        pair_value     1
# pair     ('l', 't')        pair_value     1
# pair     ('n', 'g')        pair_value     1
# pair     ('4', '2')        pair_value     1
# pair     ('o', 'o')        pair_value     1
# pair     ('o', 'g')        pair_value     2
# pair     ('a', 'r')        pair_value     2
# pair     ('r', 'l')        pair_value     1
# pair     ('s', 'l')        pair_value     1
# pair     ('e', 'e')        pair_value     1
# pair     ('y', 'b')        pair_value     1
# pair     ('b', 'o')        pair_value     1
# pair     ('r', 'd')        pair_value     1
# pair     ('r', 'r')        pair_value     1
# merge pair: ('t', 'e')
# updated tokens: ['i', 'm', 'p', 'o', 'r', 't', '</w>', 'p', 's', 'u', 't', 'i', 'l', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 't', 'i', 'm', 'e', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 'c', 's', 'v', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 'o', 's', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 'p', 'l', 'a', 't', 'f', 'o', 'r', 'm', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 'h', 'a', 's', 'h', 'l', 'i', 'b', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 'j', 's', 'o', 'n', '</w>', 'f', 'r', 'o', 'm', '</w>', 'd', 'a', 'te', 't', 'i', 'm', 'e', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 'd', 'a', 'te', 't', 'i', 'm', 'e', '</w>', '</w>', '</w>', 'o', 'p', 't', 'i', 'o', 'n', 'a', 'l', '</w>', 'g', 'p', 'u', '</w>', 'n', 'v', 'i', 'd', 'i', 'a', '</w>', 't', 'r', 'y', '</w>', '</w>', '</w>', '</w>', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 'p', 'y', 'n', 'v', 'm', 'l', '</w>', '</w>', '</w>', '</w>', '</w>', 'p', 'y', 'n', 'v', 'm', 'l', 'n', 'v', 'm', 'l', 'i', 'n', 'i', 't', '</w>', '</w>', '</w>', '</w>', '</w>', 'g', 'p', 'u', 'a', 'v', 'a', 'i', 'l', 'a', 'b', 'l', 'e', '</w>', '</w>', 't', 'r', 'u', 'e', '</w>', 'e', 'x', 'c', 'e', 'p', 't', '</w>', '</w>', '</w>', '</w>', '</w>', 'g', 'p', 'u', 'a', 'v', 'a', 'i', 'l', 'a', 'b', 'l', 'e', '</w>', '</w>', 'f', 'a', 'l', 's', 'e', '</w>', '</w>', 'b', 'a', 's', 'e', 'd', 'i', 'r', '</w>', '</w>', 's', 'y', 's', 'te', 'm', 'm', 'o', 'n', 'i', 't', 'o', 'r', '</w>', 'd', 'a', 't', 'a', 'd', 'i', 'r', '</w>', '</w>', 'o', 's', 'p', 'a', 't', 'h', 'j', 'o', 'i', 'n', 'b', 'a', 's', 'e', 'd', 'i', 'r', '</w>', 'd', 'a', 't', 'a', '</w>', 'o', 's', 'm', 'a', 'k', 'e', 'd', 'i', 'r', 's', 'd', 'a', 't', 'a', 'd', 'i', 'r', '</w>', 'e', 'x', 'i', 's', 't', 'o', 'k', 't', 'r', 'u', 'e', '</w>', '</w>', 's', 'y', 's', 'te', 'm', 'f', 'i', 'l', 'e', '</w>', '</w>', 'o', 's', 'p', 'a', 't', 'h', 'j', 'o', 'i', 'n', 'd', 'a', 't', 'a', 'd', 'i', 'r', '</w>', 's', 'y', 's', 'te', 'm', 'm', 'e', 't', 'r', 'i', 'c', 's', 'c', 's', 'v', '</w>', 'p', 'r', 'o', 'c', 'e', 's', 's', 'f', 'i', 'l', 'e', '</w>', '</w>', 'o', 's', 'p', 'a', 't', 'h', 'j', 'o', 'i', 'n', 'd', 'a', 't', 'a', 'd', 'i', 'r', '</w>', 'p', 'r', 'o', 'c', 'e', 's', 's', 'm', 'e', 't', 'r', 'i', 'c', 's', 'c', 's', 'v', '</w>', 'g', 'p', 'u', 'f', 'i', 'l', 'e', '</w>', '</w>', 'o', 's', 'p', 'a', 't', 'h', 'j', 'o', 'i', 'n', 'd', 'a', 't', 'a', 'd', 'i', 'r', '</w>', 'g', 'p', 'u', 'm', 'e', 't', 'r', 'i', 'c', 's', 'c', 's', 'v', '</w>', '</w>', 's', 'y', 's', 'te', 'm', 'i', 'n', 'te', 'r', 'v', 'a', 'l', '</w>', '</w>', '5', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>
 's'): 1, ('v', 'e'): 3, ('e', 'r'): 27, ('m', 'v'): 1, ('c', 'p'): 9, ('m', 'g'): 1, ('g', 'b'): 1, ('o', 'u'): 6, ('u', 'n'): 3, ('d', 'p'): 4, ('l', 'v'): 2, ('l', 'm'): 2, ('y', 't'): 1, ('1', '0'): 6, ('0', '2'): 6, ('2', '4'): 6, ('4', '3'): 1, ('p', 'e'): 25, ('n', 'm'): 1, ('d', 'u'): 1, ('p', 'm'): 2, ('n', 't'): 20, ('t', '4'): 1, ('v', 'f'): 1, ('e', 'a'): 6, ('e', 'w'): 4, ('w', 'l'): 4, ('w', 'r'): 20, ('i', 'te'): 21, ('v', 'w'): 4, ('r', 'f'): 4, ('r', 'w'): 4, ('w', 'h'): 2, ('v', 's'): 1, ('u', 'p'): 7, ('r', 'c'): 16, ('l', 'o'): 8, ('o', 'a'): 6, ('d', '1'): 1, ('1', 'm'): 1, ('m', 'u'): 3, ('u', 's'): 3, ('s', 'k'): 10, ('k', 'r'): 4, ('d', 'k'): 1, ('k', 'b'): 4, ('b', 'p'): 4, ('k', 'w'): 4, ('te', 'k'): 1, ('n', 'k'): 1, ('t', 'k'): 1, ('t', 'te'): 10, ('y', 'p'): 8, ('r', 'p'): 3, ('l', 'u'): 4, ('u', 'g'): 4, ('g', 'g'): 6, ('v', 'p'): 1, ('s', 'n'): 1, ('v', 'g'): 3, ('u', 'u'): 1, ('l', 'p'): 2, ('d', 'm'): 1, ('m', 'b'): 2, ('u', 'te'): 1, ('p', 'c'): 2, ('o', 'l'): 7, ('l', 'l'): 7, ('c', 't'): 8, ('l', 'c'): 2, ('l', 'g'): 2, ('t', 'l'): 3, ('g', '0'): 1, ('s', 'a'): 2, ('t', 't'): 1, ('e', 'l'): 3, ('l', 'd'): 5, ('k', 'i'): 1, ('d', 'b'): 1, ('b', 'y'): 5, ('y', 'te'): 4, ('te', 's'): 5, ('te', 'b'): 1, ('t', 'b'): 2, ('s', 'r'): 1, ('c', 'v'): 1, (' ...
# pair     ('i', 'm')        pair_value     26
# max count     26
# pair     ('m', 'p')        pair_value     25
# pair     ('p', 'o')        pair_value     11
# pair     ('o', 'r')        pair_value     28
# max count     28
# pair     ('r', 't')        pair_value     11
# pair     ('p', 's')        pair_value     15
# pair     ('s', 'u')        pair_value     10
# pair     ('u', 't')        pair_value     19
# pair     ('t', 'i')        pair_value     39
# max count     39
# pair     ('i', 'l')        pair_value     34
# pair     ('m', 'e')        pair_value     49
# max count     49
# pair     ('c', 's')        pair_value     22
# pair     ('s', 'v')        pair_value     14
# pair     ('o', 's')        pair_value     11
# pair     ('p', 'l')        pair_value     10
# pair     ('l', 'a')        pair_value     13
# pair     ('a', 't')        pair_value     33
# pair     ('t', 'f')        pair_value     6
# pair     ('f', 'o')        pair_value     12
# pair     ('r', 'm')        pair_value     7
# pair     ('h', 'a')        pair_value     9
# pair     ('a', 's')        pair_value     16
# pair     ('s', 'h')        pair_value     4
# pair     ('h', 'l')        pair_value     2
# pair     ('l', 'i')        pair_value     8
# pair     ('i', 'b')        pair_value     2
# pair     ('j', 's')        pair_value     3
# pair     ('s', 'o')        pair_value     8
# pair     ('o', 'n')        pair_value     13
# pair     ('f', 'r')        pair_value     1
# pair     ('r', 'o')        pair_value     26
# pair     ('o', 'm')        pair_value     1
# pair     ('d', 'a')        pair_value     12
# pair     ('a', 'te')        pair_value     4
# pair     ('te', 't')        pair_value     3
# pair     ('o', 'p')        pair_value     13
# pair     ('p', 't')        pair_value     6
# pair     ('i', 'o')        pair_value     7
# pair     ('n', 'a')        pair_value     4
# pair     ('a', 'l')        pair_value     9
# pair     ('g', 'p')        pair_value     15
# pair     ('p', 'u')        pair_value     24
# pair     ('n', 'v')        pair_value     14
# pair     ('v', 'i')        pair_value     7
# pair     ('i', 'd')        pair_value     12
# pair     ('d', 'i')        pair_value     22
# pair     ('i', 'a')        pair_value     1
# pair     ('t', 'r')        pair_value     20
# pair     ('r', 'y')        pair_value     18
# pair     ('p', 'y')        pair_value     7
# pair     ('y', 'n')        pair_value     7
# pair     ('v', 'm')        pair_value     13
# pair     ('m', 'l')        pair_value     13
# pair     ('l', 'n')        pair_value     7
# pair     ('i', 'n')        pair_value     45
# pair     ('n', 'i')        pair_value     7
# pair     ('i', 't')        pair_value     12
# pair     ('u', 'a')        pair_value     5
# pair     ('a', 'v')        pair_value     5
# pair     ('v', 'a')        pair_value     7
# pair     ('a', 'i')        pair_value     4
# pair     ('a', 'b')        pair_value     3
# pair     ('b', 'l')        pair_value     3
# pair     ('l', 'e')        pair_value     32
# pair     ('r', 'u')        pair_value     5
# pair     ('u', 'e')        pair_value     4
# pair     ('e', 'x')        pair_value     9
# pair     ('x', 'c')        pair_value     5
# pair     ('c', 'e')        pair_value     44
# pair     ('e', 'p')        pair_value     5
# pair     ('f', 'a')        pair_value     1
# pair     ('l', 's')        pair_value     6
# pair     ('s', 'e')        pair_value     20
# pair     ('b', 'a')        pair_value     12
# pair     ('e', 'd')        pair_value     12
# pair     ('i', 'r')        pair_value     11
# pair     ('s', 'y')        pair_value     11
# pair     ('y', 's')        pair_value     11
# pair     ('s', 'te')        pair_value     11
# pair     ('te', 'm')        pair_value     16
# pair     ('m', 'm')        pair_value     4
# pair     ('m', 'o')        pair_value     6
# pair     ('t', 'o')        pair_value     13
# pair     ('t', 'a')        pair_value     22
# pair     ('a', 'd')        pair_value     16
# pair     ('s', 'p')        pair_value     7
# pair     ('p', 'a')        pair_value     9
# pair     ('t', 'h')        pair_value     13
# pair     ('h', 'j')        pair_value     5
# pair     ('j', 'o')        pair_value     5
# pair     ('o', 'i')        pair_value     5
# pair     ('n', 'b')        pair_value     2
# pair     ('s', 'm')        pair_value     5
# pair     ('m', 'a')        pair_value     15
# pair     ('a', 'k')        pair_value     1
# pair     ('k', 'e')        pair_value     3
# pair     ('r', 's')        pair_value     7
# pair     ('s', 'd')        pair_value     1
# pair     ('x', 'i')        pair_value     3
# pair     ('i', 's')        pair_value     14
# pair     ('s', 't')        pair_value     20
# pair     ('o', 'k')        pair_value     1
# pair     ('k', 't')        pair_value     1
# pair     ('m', 'f')        pair_value     3
# pair     ('f', 'i')        pair_value     15
# pair     ('n', 'd')        pair_value     15
# pair     ('e', 't')        pair_value     41
# pair     ('r', 'i')        pair_value     32
# pair     ('i', 'c')        pair_value     14
# pair     ('s', 'c')        pair_value     3
# pair     ('p', 'r')        pair_value     23
# pair     ('o', 'c')        pair_value     22
# pair     ('e', 's')        pair_value     35
# pair     ('s', 's')        pair_value     24
# pair     ('s', 'f')        pair_value     4
# pair     ('u', 'f')        pair_value     3
# pair     ('u', 'm')        pair_value     5
# pair     ('m', 'i')        pair_value     2
# pair     ('n', 'te')        pair_value     7
# pair     ('te', 'r')        pair_value     33
# pair     ('r', 'v')        pair_value     4
# pair     ('e', 'c')        pair_value     10
# pair     ('c', 'o')        pair_value     12
# pair     ('d', 's')        pair_value     2
# pair     ('s', 'i')        pair_value     5
# pair     ('3', '0')        pair_value     1
# pair     ('p', 'n')        pair_value     3
# pair     ('n', 'p')        pair_value     3
# pair     ('d', 'e')        pair_value     16
# pair     ('e', 'f')        pair_value     6
# pair     ('g', 'e')        pair_value     15
# pair     ('t', 'm')        pair_value     3
# pair     ('a', 'c')        pair_value     12
# pair     ('c', 'h')        pair_value     12
# pair     ('h', 'i')        pair_value     13
# pair     ('n', 'e')        pair_value     32
# pair     ('e', 'i')        pair_value     11
# pair     ('r', 'a')        pair_value     6
# pair     ('a', 'w')        pair_value     2
# pair     ('m', 'n')        pair_value     1
# pair     ('n', 'o')        pair_value     10
# pair     ('o', 'd')        pair_value     2
# pair     ('r', 'e')        pair_value     12
# pair     ('t', 'u')        pair_value     8
# pair     ('u', 'r')        pair_value     5
# pair     ('r', 'n')        pair_value     4
# pair     ('b', 's')        pair_value     1
# pair     ('a', '2')        pair_value     1
# pair     ('2', '5')        pair_value     1
# pair     ('5', '6')        pair_value     1
# pair     ('6', 'r')        pair_value     1
# pair     ('w', 'e')        pair_value     3
# pair     ('e', 'n')        pair_value     26
# pair     ('n', 'c')        pair_value     1
# pair     ('e', 'h')        pair_value     2
# pair     ('h', 'e')        pair_value     5
# pair     ('x', 'd')        pair_value     1
# pair     ('i', 'g')        pair_value     1
# pair     ('t', '1')        pair_value     1
# pair     ('1', '2')        pair_value     1
# pair     ('a', 'm')        pair_value     12
# pair     ('e', 'u')        pair_value     1
# pair     ('t', 'c')        pair_value     5
# pair     ('c', 'n')        pair_value     1
# pair     ('o', 'w')        pair_value     10
# pair     ('w', 'i')        pair_value     6
# pair     ('o', 'f')        pair_value     1
# pair     ('n', 'f')        pair_value     4
# pair     ('a', 'f')        pair_value     3
# pair     ('e', 'm')        pair_value     13
# pair     ('a', 'j')        pair_value     1
# pair     ('i', 'f')        pair_value     7
# pair     ('o', 't')        pair_value     4
# pair     ('t', 's')        pair_value     5
# pair     ('m', 's')        pair_value     1
# pair     ('v', 'e')        pair_value     3
# pair     ('e', 'r')        pair_value     27
# pair     ('m', 'v')        pair_value     1
# pair     ('c', 'p')        pair_value     9
# pair     ('m', 'g')        pair_value     1
# pair     ('g', 'b')        pair_value     1
# pair     ('o', 'u')        pair_value     6
# pair     ('u', 'n')        pair_value     3
# pair     ('d', 'p')        pair_value     4
# pair     ('l', 'v')        pair_value     2
# pair     ('l', 'm')        pair_value     2
# pair     ('y', 't')        pair_value     1
# pair     ('1', '0')        pair_value     6
# pair     ('0', '2')        pair_value     6
# pair     ('2', '4')        pair_value     6
# pair     ('4', '3')        pair_value     1
# pair     ('p', 'e')        pair_value     25
# pair     ('n', 'm')        pair_value     1
# pair     ('d', 'u')        pair_value     1
# pair     ('p', 'm')        pair_value     2
# pair     ('n', 't')        pair_value     20
# pair     ('t', '4')        pair_value     1
# pair     ('v', 'f')        pair_value     1
# pair     ('e', 'a')        pair_value     6
# pair     ('e', 'w')        pair_value     4
# pair     ('w', 'l')        pair_value     4
# pair     ('w', 'r')        pair_value     20
# pair     ('i', 'te')        pair_value     21
# pair     ('v', 'w')        pair_value     4
# pair     ('r', 'f')        pair_value     4
# pair     ('r', 'w')        pair_value     4
# pair     ('w', 'h')        pair_value     2
# pair     ('v', 's')        pair_value     1
# pair     ('u', 'p')        pair_value     7
# pair     ('r', 'c')        pair_value     16
# pair     ('l', 'o')        pair_value     8
# pair     ('o', 'a')        pair_value     6
# pair     ('d', '1')        pair_value     1
# pair     ('1', 'm')        pair_value     1
# pair     ('m', 'u')        pair_value     3
# pair     ('u', 's')        pair_value     3
# pair     ('s', 'k')        pair_value     10
# pair     ('k', 'r')        pair_value     4
# pair     ('d', 'k')        pair_value     1
# pair     ('k', 'b')        pair_value     4
# pair     ('b', 'p')        pair_value     4
# pair     ('k', 'w')        pair_value     4
# pair     ('te', 'k')        pair_value     1
# pair     ('n', 'k')        pair_value     1
# pair     ('t', 'k')        pair_value     1
# pair     ('t', 'te')        pair_value     10
# pair     ('y', 'p')        pair_value     8
# pair     ('r', 'p')        pair_value     3
# pair     ('l', 'u')        pair_value     4
# pair     ('u', 'g')        pair_value     4
# pair     ('g', 'g')        pair_value     6
# pair     ('v', 'p')        pair_value     1
# pair     ('s', 'n')        pair_value     1
# pair     ('v', 'g')        pair_value     3
# pair     ('u', 'u')        pair_value     1
# pair     ('l', 'p')        pair_value     2
# pair     ('d', 'm')        pair_value     1
# pair     ('m', 'b')        pair_value     2
# pair     ('u', 'te')        pair_value     1
# pair     ('p', 'c')        pair_value     2
# pair     ('o', 'l')        pair_value     7
# pair     ('l', 'l')        pair_value     7
# pair     ('c', 't')        pair_value     8
# pair     ('l', 'c')        pair_value     2
# pair     ('l', 'g')        pair_value     2
# pair     ('t', 'l')        pair_value     3
# pair     ('g', '0')        pair_value     1
# pair     ('s', 'a')        pair_value     2
# pair     ('t', 't')        pair_value     1
# pair     ('e', 'l')        pair_value     3
# pair     ('l', 'd')        pair_value     5
# pair     ('k', 'i')        pair_value     1
# pair     ('d', 'b')        pair_value     1
# pair     ('b', 'y')        pair_value     5
# pair     ('y', 'te')        pair_value     4
# pair     ('te', 's')        pair_value     5
# pair     ('te', 'b')        pair_value     1
# pair     ('t', 'b')        pair_value     2
# pair     ('s', 'r')        pair_value     1
# pair     ('c', 'v')        pair_value     1
# pair     ('n', 's')        pair_value     2
# pair     ('s', 'b')        pair_value     1
# pair     ('t', 'p')        pair_value     5
# pair     ('a', 'p')        pair_value     1
# pair     ('p', 'p')        pair_value     2
# pair     ('p', 'i')        pair_value     1
# pair     ('r', 'te')        pair_value     2
# pair     ('te', 'd')        pair_value     2
# pair     ('e', 'y')        pair_value     2
# pair     ('y', 'l')        pair_value     1
# pair     ('b', 'd')        pair_value     1
# pair     ('e', 'v')        pair_value     5
# pair     ('t', 'g')        pair_value     2
# pair     ('a', 'n')        pair_value     5
# pair     ('d', 'l')        pair_value     5
# pair     ('e', 'g')        pair_value     5
# pair     ('e', 'b')        pair_value     1
# pair     ('y', 'i')        pair_value     2
# pair     ('x', '0')        pair_value     1
# pair     ('i', 'z')        pair_value     1
# pair     ('z', 'a')        pair_value     1
# pair     ('n', 'r')        pair_value     1
# pair     ('o', 'h')        pair_value     1
# pair     ('l', 'te')        pair_value     1
# pair     ('n', 'g')        pair_value     1
# pair     ('4', '2')        pair_value     1
# pair     ('o', 'o')        pair_value     1
# pair     ('o', 'g')        pair_value     2
# pair     ('a', 'r')        pair_value     2
# pair     ('r', 'l')        pair_value     1
# pair     ('s', 'l')        pair_value     1
# pair     ('e', 'e')        pair_value     1
# pair     ('y', 'b')        pair_value     1
# pair     ('b', 'o')        pair_value     1
# pair     ('r', 'd')        pair_value     1
# pair     ('r', 'r')        pair_value     1
# merge pair: ('m', 'e')
# updated tokens: ['i', 'm', 'p', 'o', 'r', 't', '</w>', 'p', 's', 'u', 't', 'i', 'l', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 't', 'i', 'me', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 'c', 's', 'v', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 'o', 's', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 'p', 'l', 'a', 't', 'f', 'o', 'r', 'm', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 'h', 'a', 's', 'h', 'l', 'i', 'b', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 'j', 's', 'o', 'n', '</w>', 'f', 'r', 'o', 'm', '</w>', 'd', 'a', 'te', 't', 'i', 'me', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 'd', 'a', 'te', 't', 'i', 'me', '</w>', '</w>', '</w>', 'o', 'p', 't', 'i', 'o', 'n', 'a', 'l', '</w>', 'g', 'p', 'u', '</w>', 'n', 'v', 'i', 'd', 'i', 'a', '</w>', 't', 'r', 'y', '</w>', '</w>', '</w>', '</w>', '</w>', 'i', 'm', 'p', 'o', 'r', 't', '</w>', 'p', 'y', 'n', 'v', 'm', 'l', '</w>', '</w>', '</w>', '</w>', '</w>', 'p', 'y', 'n', 'v', 'm', 'l', 'n', 'v', 'm', 'l', 'i', 'n', 'i', 't', '</w>', '</w>', '</w>', '</w>', '</w>', 'g', 'p', 'u', 'a', 'v', 'a', 'i', 'l', 'a', 'b', 'l', 'e', '</w>', '</w>', 't', 'r', 'u', 'e', '</w>', 'e', 'x', 'c', 'e', 'p', 't', '</w>', '</w>', '</w>', '</w>', '</w>', 'g', 'p', 'u', 'a', 'v', 'a', 'i', 'l', 'a', 'b', 'l', 'e', '</w>', '</w>', 'f', 'a', 'l', 's', 'e', '</w>', '</w>', 'b', 'a', 's', 'e',
 'm', 'a', 'c', 'h', 'i', 'n', 'e', 'i', 'd', '</w>', '</w>', 'g', 'e', 't', 'm', 'a', 'c', 'h', 'i', 'n', 'e', 'i', 'd', '</w>', '</w>', 'd', 'e', 'f', '</w>', 't', 'i', 'me', 's', 't', 'a', 'm', 'p', '</w>', '</w>', '</w>', '</w>', '</w>', 'r', 'e', 't', 'u', 'r', 'n', '</w>', 'd', 'a', 'te', 't', 'i', 'me', 'u', 't', 'c', 'n', 'o', 'w', 'i', 's', 'o', 'f', 'o', 'r', 'm', 'a', 't', '</w>' ...
# dcount_pair
# ...
# pair     ('d', 'in')        pair_value     1
# pair     ('ter', 'r')        pair_value     1
# pair     ('u', 'p')        pair_value     1
# pair     ('t', 'l')        pair_value     1
# pair     ('op', 'p')        pair_value     1
# merge pair: ('s', 'ystem')
# updated tokens: ['i', 'mp', 'or', 't', '</w>', 'psutil', '</w>', 'i', 'mp', 'or', 't', '</w>', 'time', '</w>', 'i', 'mp', 'or', 't', '</w>', 'csv', '</w>', 'i', 'mp', 'or', 't', '</w>', 'os', '</w>', 'i', 'mp', 'or', 't', '</w>', 'pl', 'at', 'f', 'or', 'm', '</w>', 'i', 'mp', 'or', 't', '</w>', 'h', 'a', 's', 'h', 'l', 'i', 'b', '</w>', 'i', 'mp', 'or', 't', '</w>', 'j', 's', 'on', '</w>', 'f', 'ro', 'm', '</w>', 'd', 'a', 'te', 'time', '</w>', 'i', 'mp', 'or', 't', '</w>', 'd', 'a', 'te', 'time', '</w>', '</w>', '</w>', 'op', 'ti', 'on', 'a', 'l', '</w>', 'gpu', '</w>', 'nv', 'i', 'di', 'a', '</w>', 't', 'r', 'y', '</w>', '</w>', '</w>', '</w>', '</w>', 'i', 'mp', 'or', 't', '</w>', 'p', 'y', 'nvml', '</w>', '</w>', '</w>', '</w>', '</w>', 'p', 'y', 'nvml', 'nvml', 'in', 'it', '</w>', '</w>', '</w>', '</w>', '</w>', 'gpu', 'a', 'v', 'a', 'i', 'l', 'a', 'b', 'le', '</w>', '</w>', 't', 'r', 'u', 'e', '</w>', 'e', 'x', 'ce', 'p', 't', '</w>', '</w>', '</w>', '</w>', '</w>', 'gpu', 'a', 'v', 'a', 'i', 'l', 'a', 'b', 'le', '</w>', '</w>', 'f', 'a', 'l', 'se', '</w>', '</w>', 'b', 'a', 'se', 'di', 'r', '</w>', '</w>', 'system', 'm', 'on', 'it', 'or', '</w>', 'd', 'at', 'a', 'di', 'r', '</w>', '</w>', 'os', 'p', 'at', 'h', 'j', 'o', 'in', 'b', 'a', 'se', 'di', 'r', '</w>', 'd', 'at', 'a', '</w>', 'os', 'ma', 'k', 'e', 'di', 'r', 's', 'd', 'at', 'a', 'di', 'r', '</w>', 'e', 'x', 'i', 'st', 'o', 'k', 't', 'r', 'u', 'e', '</w>', '</w>', 'system', 'file', '</w>', '</w>', 'os', 'p', 'at', 'h', 'j', 'o', 'in', 'd', 'at', 'a', 'di', 'r', '</w>', 'system', 'met', 'ri', 'cs', 'csv', '</w>', 'process', 'file', '</w>', '</w>', 'os', 'p', 'at', 'h', 'j', 'o', 'in', 'd', 'at', 'a', 'di', 'r', '</w>', 'process', 'met', 'ri', 'cs', 'csv', '</w>', 'gpu', 'file', '</w>', '</w>', 'os', 'p', 'at', 'h', 'j', 'o', 'in', 'd', 'at', 'a', 'di', 'r', '</w>', 'gpu', 'met', 'ri', 'cs', 'csv', '</w>', '</w>', 'system', 'in', 'ter', 'v', 'a', 'l', '</w>', '</w>', '5', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', 'se', 'c', 'on', 'd', 's', '</w>', 'process', 'in', 'ter', 'v', 'a', 'l', '</w>', '</w>', '3', '0', '</w>', '</w>', '</w>', '</w>', '</w>', 'se', 'c', 'on', 'd', 's', '</w>', 't', 'op', 'n', 'process', 'e', 's', '</w>', '</w>', '5', '</w>', '</w>', '</w>', '</w>', 'util', 's', '</w>', '</w>', '</w>', 'de', 'f', '</w>', 'g', 'et', 'machineid', '</w>', '</w>', '</w>', '</w>', '</w>', 'r', 'a', 'w', '</w>', '</w>', 'pl', 'at', 'f', 'or', 'm', 'n', 'o', 'de', '</w>', '</w>', 'pl', 'at', 'f', 'or', 'mp', 'rocess', 'or', '</w>', '</w>', '</w>', '</w>', '</w>', 'r', 'et', 'u', 'r', 'n', '</w>', 'h', 'a', 's', 'h', 'l', 'i', 'b', 's', 'h', 'a', '2', '5', '6', 'r', 'a', 'w', 'e', 'n', 'c', 'o', 'de', 'h', 'e', 'x', 'di', 'g', 'e', 'st', '1', '2', '</w>', '</w>', 'machineid', '</w>', '</w>', 'g', 'et', 'machineid', '</w>', '</w>', 'de', 'f', '</w>', 'time', 'st', 'a', 'mp', '</w>', '</w>', '</w>', '</w>', '</w>', 'r', 'et', 'u', 'r', 'n', '</w>', 'd', 'a', 'te', 'time', 'u', 't', 'c', 'n', 'o', 'w', 'i', 's', 'o', 'f', 'or', 'm', 'at', '</w>', '</w>', '</w>', '</w>', 'met', 'a', '</w>', 'in', 'f', 'o', '</w>', '</w>', '</w>', 'met', 'a', 'file', '</w>', '</w>', 'os', 'p', 'at', 'h', 'j', 'o', 'in', 'b', 'a', 'se', 'di', 'r', '</w>', 'machine', 'met', 'a', 'j', 's', 'on', '</w>', 'i', 'f', '</w>', 'n', 'o', 't', '</w>', 'os', 'p', 'at', 'h', 'e', 'x', 'i', 'st', 's', 'met', 'a', 'file', '</w>', '</w>', '</w>', '</w>', '</w>', 'met', 'a', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', 'machineid', '</w>', 'machineid', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', 'os', '</w>', 'pl', 'at', 'f', 'or', 'm', 'system', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', 'os', 'v', 'er', 's', 'i', 'on', '</w>', 'pl', 'at', 'f', 'or', 'm', 'v', 'er', 's', 'i', 'on', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>', '</w>
# pair     ('l', 'i')        pair_value     2
# pair     ('i', 'b')        pair_value     2
# pair     ('j', 's')        pair_value     3
# pair     ('s', 'on')        pair_value     3
# pair     ('f', 'ro')        pair_value     1
# pair     ('ro', 'm')        pair_value     1
# pair     ('d', 'a')        pair_value     4
# pair     ('a', 'te')        pair_value     4
# pair     ('te', 'time')        pair_value     3
# pair     ('op', 'ti')        pair_value     1
# pair     ('ti', 'on')        pair_value     3
# pair     ('on', 'a')        pair_value     1
# pair     ('a', 'l')        pair_value     9
# pair     ('nv', 'i')        pair_value     1
# pair     ('i', 'di')        pair_value     1
# pair     ('di', 'a')        pair_value     1
# pair     ('t', 'r')        pair_value     9
# pair     ('r', 'y')        pair_value     4
# pair     ('p', 'y')        pair_value     7
# pair     ('y', 'nvml')        pair_value     7
# pair     ('nvml', 'nvml')        pair_value     6
# pair     ('nvml', 'in')        pair_value     1
# pair     ('in', 'it')        pair_value     6
# pair     ('gpu', 'a')        pair_value     3
# pair     ('a', 'v')        pair_value     5
# pair     ('v', 'a')        pair_value     7
# pair     ('a', 'i')        pair_value     3
# pair     ('i', 'l')        pair_value     3
# pair     ('l', 'a')        pair_value     7
# pair     ('a', 'b')        pair_value     3
# pair     ('b', 'le')        pair_value     3
# pair     ('r', 'u')        pair_value     5
# pair     ('u', 'e')        pair_value     3
# pair     ('e', 'x')        pair_value     8
# pair     ('x', 'ce')        pair_value     4
# pair     ('ce', 'p')        pair_value     4
# pair     ('p', 't')        pair_value     5
# pair     ('f', 'a')        pair_value     1
# pair     ('l', 'se')        pair_value     4
# pair     ('b', 'a')        pair_value     3
# pair     ('a', 'se')        pair_value     3
# pair     ('se', 'di')        pair_value     3
# pair     ('di', 'r')        pair_value     9
# pair     ('system', 'm')        pair_value     1
# pair     ('m', 'on')        pair_value     1
# pair     ('on', 'it')        pair_value     1
# pair     ('it', 'or')        pair_value     1
# pair     ('d', 'at')        pair_value     6
# pair     ('at', 'a')        pair_value     6
# pair     ('a', 'di')        pair_value     5
# pair     ('os', 'p')        pair_value     7
# pair     ('p', 'at')        pair_value     7
# pair     ('at', 'h')        pair_value     7
# pair     ('h', 'j')        pair_value     5
# pair     ('j', 'o')        pair_value     5
# pair     ('o', 'in')        pair_value     5
# pair     ('in', 'b')        pair_value     2
# pair     ('os', 'ma')        pair_value     1
# pair     ('ma', 'k')        pair_value     1
# pair     ('k', 'e')        pair_value     3
# pair     ('e', 'di')        pair_value     1
# pair     ('r', 's')        pair_value     1
# pair     ('s', 'd')        pair_value     1
# pair     ('x', 'i')        pair_value     3
# pair     ('i', 'st')        pair_value     3
# pair     ('st', 'o')        pair_value     1
# pair     ('o', 'k')        pair_value     1
# pair     ('k', 't')        pair_value     1
# pair     ('system', 'file')        pair_value     3
# pair     ('in', 'd')        pair_value     3
# pair     ('system', 'met')        pair_value     3
# pair     ('met', 'ri')        pair_value     10
# max count     10
# pair     ('ri', 'cs')        pair_value     9
# pair     ('cs', 'csv')        pair_value     3
# pair     ('process', 'file')        pair_value     3
# pair     ('process', 'met')        pair_value     3
# pair     ('gpu', 'file')        pair_value     3
# pair     ('gpu', 'met')        pair_value     3
# pair     ('system', 'in')        pair_value     1
# pair     ('in', 'ter')        pair_value     5
# pair     ('ter', 'v')        pair_value     4
# pair     ('se', 'c')        pair_value     2
# pair     ('c', 'on')        pair_value     2
# pair     ('on', 'd')        pair_value     3
# pair     ('d', 's')        pair_value     2
# pair     ('process', 'in')        pair_value     2
# pair     ('3', '0')        pair_value     1
# pair     ('t', 'op')        pair_value     3
# pair     ('op', 'n')        pair_value     2
# pair     ('n', 'process')        pair_value     3
# pair     ('process', 'e')        pair_value     5
# pair     ('e', 's')        pair_value     5
# pair     ('util', 's')        pair_value     1
# pair     ('de', 'f')        pair_value     6
# pair     ('g', 'et')        pair_value     8
# pair     ('et', 'machineid')        pair_value     2
# pair     ('r', 'a')        pair_value     4
# pair     ('a', 'w')        pair_value     2
# pair     ('m', 'n')        pair_value     1
# pair     ('n', 'o')        pair_value     8
# pair     ('o', 'de')        pair_value     2
# pair     ('or', 'mp')        pair_value     2
# pair     ('mp', 'rocess')        pair_value     2
# pair     ('rocess', 'or')        pair_value     2
# pair     ('r', 'et')        pair_value     3
# pair     ('et', 'u')        pair_value     3
# pair     ('u', 'r')        pair_value     5
# pair     ('r', 'n')        pair_value     3
# pair     ('b', 's')        pair_value     1
# pair     ('a', '2')        pair_value     1
# pair     ('2', '5')        pair_value     1
# pair     ('5', '6')        pair_value     1
# pair     ('6', 'r')        pair_value     1
# pair     ('w', 'e')        pair_value     1
# pair     ('e', 'n')        pair_value     7
# pair     ('n', 'c')        pair_value     1
# pair     ('c', 'o')        pair_value     10
# pair     ('de', 'h')        pair_value     1
# pair     ('h', 'e')        pair_value     5
# pair     ('x', 'di')        pair_value     1
# pair     ('di', 'g')        pair_value     1
# pair     ('g', 'e')        pair_value     5
# pair     ('e', 'st')        pair_value     1
# pair     ('st', '1')        pair_value     1
# pair     ('1', '2')        pair_value     1
# pair     ('time', 'st')        pair_value     7
# pair     ('st', 'a')        pair_value     8
# pair     ('a', 'mp')        pair_value     7
# pair     ('time', 'u')        pair_value     1
# pair     ('u', 't')        pair_value     4
# pair     ('t', 'c')        pair_value     1
# pair     ('c', 'n')        pair_value     1
# pair     ('o', 'w')        pair_value     10
# pair     ('w', 'i')        pair_value     1
# pair     ('i', 's')        pair_value     1
# pair     ('s', 'o')        pair_value     1
# pair     ('o', 'f')        pair_value     1
# pair     ('m', 'at')        pair_value     1
# pair     ('met', 'a')        pair_value     7
# pair     ('in', 'f')        pair_value     3
# pair     ('f', 'o')        pair_value     3
# pair     ('a', 'file')        pair_value     3
# pair     ('machine', 'met')        pair_value     1
# pair     ('a', 'j')        pair_value     1
# pair     ('i', 'f')        pair_value     7
# pair     ('o', 't')        pair_value     4
# pair     ('st', 's')        pair_value     2
# pair     ('s', 'met')        pair_value     1
# pair     ('m', 'system')        pair_value     1
# pair     ('os', 'v')        pair_value     1
# pair     ('v', 'er')        pair_value     3
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
