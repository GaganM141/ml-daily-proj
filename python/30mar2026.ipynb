# %%
# D
n=7
for i in range(1,n+1):
    if i==1 or i==n:
        print('*'*(n-1))
    else:
        print('*'+' '*(n-2)+'*')
# Out:
# ******
# *     *
# *     *
# *     *
# *     *
# *     *
# ******

# %%
#E
for i in range(1,n+1):
    if i==1 or i==n or i==n//2+1:
        print('*'*n)
    else:
        print('*')
# Out:
# *******
# *
# *
# *******
# *
# *
# *******

# %%
#F
for i in range(1,n+1):
    if i==1 or i==n//2+1:
        print('*'*n)
    else:
        print('*')
# Out:
# *******
# *
# *
# *******
# *
# *
# *

# %%
#G
for i in range(1,n+1):
    if i==1 or i==n:
        print('*'*n)
    elif i<=n//2 :
        print('*')
    elif i==n//2+1:
        print('*'+' '*(n//2)+'*'*(n//2))
        
    else:
        print('*'+' '*(n-2)+'*')
# Out:
# *******
# *
# *
# *   ***
# *     *
# *     *
# *******

# %%
#H
for i in range(1,n+1):
    if i==n//2+1:
        print('*'*n)
    else:
        print('*'+' '*(n-2)+'*')
# Out:
# *     *
# *     *
# *     *
# *******
# *     *
# *     *
# *     *

# %%
#I
for i in range(1,n+1):
    if i==1 or i==n:
        print('*'*n)
    else:
        print(' '*(n//2)+'*')
# Out:
# *******
#    *
#    *
#    *
#    *
#    *
# *******

# %%
#J
for i in range(1,n+1):
    if i==1 or i==n:
        print('*'*n)
    elif i<n//2+1:
        print(' '*(n-1)+'*')
    else:
        print('*'+" "*(n-2)+'*')
        m+=1
# Out:
# *******
#       *
#       *
# *     *
# *     *
# *     *
# *******

# %%
#K
j=n-1
s=1
for i in range(1,n+1):
    if i<=n//2+1:
        print('*'+' '*j+'*')
        j-=2
    else:
        print('*'+' '*s+'*')
        s+=2
# Out:
# *      *
# *    *
# *  *
# **
# * *
# *   *
# *     *

# %%
#L
for i in range(1,n+1):
    if i==n:
        print('*'*n)
    else:
        print('*')
# Out:
# *
# *
# *
# *
# *
# *
# *******

# %%
#M
n=7
m=0
l=n-4
for i in range(1, n+1):
    if i<=n//2+1:
        print('*'+' '*m+'*'+' '*(l*2)+'*'+' '*m+'*')
        m+=1
        l-=1
    else:
        print('*'+' '*(n+1)+'*')
# Out:
# **      **
# * *    * *
# *  *  *  *
# *   **   *
# *        *
# *        *
# *        *

# %%
#N
x=0
y=n-1
for i in range(1,n+1):
    print('*'+' '*x+'*'+' '*y+'*')
    x+=1
    y-=1
# Out:
# **      *
# * *     *
# *  *    *
# *   *   *
# *    *  *
# *     * *
# *      **

# %%
#o
q=0
r=n//2
for i in range(1,n+1):
    if i<=n//2:
        print(' '*r+'*'+' '*q+'*')
        q+=2
        r-=1
    else:
        print(' '*r+'*'+' '*q+'*')
        q-=2
        r+=1
# Out:
#    **
#   *  *
#  *    *
# *      *
#  *    *
#   *  *
#    **

# %%
#O
for i in range(1,n+1):
    if i==n or i==1:
        print(' '+'*'*(n-2)+' ')
    else:
        print('*'+' '*(n-2)+'*')
# Out:
#  *****
# *     *
# *     *
# *     *
# *     *
# *     *
#  *****
